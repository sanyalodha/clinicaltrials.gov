# %% [markdown]
# # MAPPING STUDIES TO THERAPEUTIC AREAS

# %% [markdown]
# In this Notebook, we map studies to their therapuetic areas using word embeddings. We mostly follow this [article](https://towardsdatascience.com/use-embeddings-to-predict-therapeutic-area-of-clinical-studies-654af661b949) by
# Thierry Herrmann.

# %% [markdown]
# ### IMPORTS

# %%
# Import notebook containing the studies required
# %run data_extraction1.ipynb

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns

# use the whole width
from IPython.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))

# ensure plots don't have a transparent background
plt.rcParams['axes.facecolor']='white' 
plt.rcParams['figure.facecolor']='white'

pd.set_option("display.max_rows",100)
# Out:
# <style>.container { width:80% !important; }</style>

# %% [markdown]
# ### SOME CONSTANTS

# %%
# Constants
mesh_dir = '/Users/sanya/Downloads/'
emb_dir = '/Users/sanya/Downloads/embeddings-master'

# %% [markdown]
# ## LOAD PRETRAINED EMBEDDINGS

# %% [markdown]
# - Loading pretrained embeddings of the UMLS (Unified Medical Language System) CUI's (Concept Unique Identifiers)
# - Loading using the gensim library

# %%
from gensim.models.keyedvectors import KeyedVectors
w2v_path = emb_dir+'/DeVine_etal_200.txt'     # len(w2v.vocab) = 52102
w2v = KeyedVectors.load_word2vec_format(w2v_path, binary=False) # Syntax

# %% [markdown]
# Notes:
#
#      “KeyedVectors” is essentially a mapping between keys and vectors. Each vector is identified by its lookup key, most often a short string token, so this is usually a mapping between {str => 1D numpy array}.

# %%
if False:
    w2v_path = emb_dir + '/stanford_cuis_svd_300.txt' # len(w2v.vocab) = 22705
    w2v_stanford = KeyedVectors.load_word2vec_format(w2v_path, binary=False)

# %%
if False:
    w2v_path = emb_dir + '/claims_cuis_hs_300.txt' # len(w2v.vocab) = 14852
    w2v_claims = KeyedVectors.load_word2vec_format(w2v_path, binary=False)

# %%
vocab_keys = w2v.key_to_index
len(vocab_keys)
# Out:
# 52102

# %%
# TEST CASE

w2v.most_similar('C0019158')

# Using the most_similar function from the gensim library, we can look up the CUI's that are most similar to the one we provided.

# Returns:

# [('C0012833', 0.782675564289093),     dizziness
#  ('C0220870', 0.7098520994186401),    Lightheadedness
#  ('C0917801', 0.6731902360916138),    Sleeplessness
#  ('C0043352', 0.669024646282196),     Xerostomia
#  ('C0027497', 0.6656966805458069),    Nausea
#  ('C0221512', 0.6654322147369385)]    Stomach ache
# Out:
# [('C0037140', 0.6207729578018188),
#  ('C0019196', 0.5936840772628784),
#  ('C0019163', 0.5609232187271118),
#  ('C0019169', 0.5462726950645447),
#  ('C0019159', 0.5288532972335815),
#  ('C0042721', 0.5198029279708862),
#  ('C0524909', 0.5124529004096985),
#  ('C1443861', 0.4951326549053192),
#  ('C0011226', 0.49500754475593567),
#  ('C0019189', 0.4948180317878723)]

# %%
# TEST CASE

# Find concepts similar to C0019158 hepatitis

w2v.most_similar('C0019158')

# Returns:

# [('C0037140', 0.6207730770111084),  B Virus Infection
#  ('C0019196', 0.5936840772628784),  Hepatitis C
#  ('C0019163', 0.5609232187271118),  Hepatitis B
#  ('C0019169', 0.5462726950645447),  Hepatitis B Virus
#  ('C0019159', 0.5288532376289368),  Hepatitis A
#  ('C0042721', 0.5198029279708862),  Viral hepatitis
#  ('C0524909', 0.5124529004096985),  Hepatitis B, Chronic
#  ('C1443861', 0.4951326549053192),  Post-Exposure Prophylaxis
#  ('C0011226', 0.4950075149536133),  Hepatitis D Infection
#  ('C0019189', 0.4948180317878723)]  Hepatitis, Chronic
# Out:
# [('C0037140', 0.6207729578018188),
#  ('C0019196', 0.5936840772628784),
#  ('C0019163', 0.5609232187271118),
#  ('C0019169', 0.5462726950645447),
#  ('C0019159', 0.5288532972335815),
#  ('C0042721', 0.5198029279708862),
#  ('C0524909', 0.5124529004096985),
#  ('C1443861', 0.4951326549053192),
#  ('C0011226', 0.49500754475593567),
#  ('C0019189', 0.4948180317878723)]

# %% [markdown]
# ## UTILITY FUNCTIONS

# %%
def df_mem(df):
    return '%.1f Mb' % (df.memory_usage(index=True, deep=True).values.sum()/1024/1024) 

def load_df(file_name, nrows=1000, header='infer', names=None):
    df = pd.read_csv(file_name, sep='|', nrows=nrows, low_memory=False, header=header, names=names)
    #print("loaded '%s', %d rows (%s)" % (file_name, len(df), df_mem(df)))
    return df

# %% [markdown]
# ## LOAD/ INSPECT STUDIES

# %%
# Dataframe with the required studies

data_final
# Out:
#              NCTId      ConditionMeshTerm         OverallStatus  \
# 0      NCT02335671       breast neoplasms          [Recruiting]
# 1      NCT02348749  neuroendocrine tumors          [Recruiting]
# 2      NCT02347995                 stroke          [Recruiting]
# 3      NCT02346435       kidney neoplasms          [Recruiting]
# 4      NCT02344485      parkinson disease          [Recruiting]
# ...            ...                    ...                   ...
# 32307  NCT05406583                    hiv  [Not yet recruiting]
# 32308  NCT05440786    neoplasm metastasis  [Not yet recruiting]
# 32309  NCT05427812       multiple myeloma  [Not yet recruiting]
# 32310  NCT05410145            kras p.g12c          [Recruiting]
# 32311  NCT05441501    prostatic neoplasms  [Not yet recruiting]
#
#                                                Condition  \
# 0      [Early Stage Breast Cancer, Breast Cancer Stag...
# 1                                [Neuroendocrine Tumors]
# 2                                               [Stroke]
# 3                                      [Kidney Neoplasm]
# 4                    [Parkinson's Disease, Constipation]
# ...                                                  ...
# 32307                                              [HIV]
# 32308              [Sarcoma, Ewing, Neoplasm Metastasis]
# 32309             [Relapsed/Refractory Multiple Myeloma]
# 32310                                      [KRAS P.G12C]
# 32311                              [Prostatic Neoplasms]
#
#                                         InterventionName  \
# 0      [Intra-operative Magnetic Resonance Imaging (M...
# 1      [18F-MFBG (meta-fluoro benzylguanidine), Posit...
# 2                                     [Protein, Placebo]
# 3                                                     []
# 4                                        [OMM treatment]
# ...                                                  ...
# 32307  [Dolutegravir 0.5 mg/kg oral suspension, Dolut...
# 32308            [Abemaciclib, Irinotecan, Temozolomide]
# 32309  [ISB 1442 SC injection escalating doses, ISB 1...
# 32310                                          [D3S-001]
# 32311                                     [JNJ-80038114]
#
#                                             LocationCity  \
# 0                                       [Boston, Boston]
# 1                                             [New York]
# 2                                            [Baltimore]
# 3                                            [Baltimore]
# 4                                         [Old Westbury]
# ...                                                  ...
# 32307  [Los Angeles, Los Angeles, Aurora, Atlanta, Ch...
# 32308  [Phoenix, Los Angeles, Indianapolis, Saint Lou...
# 32309  [New York, Camperdown, Benowa, Southport, Melb...
# 32310  [Detroit, Sydney, Malvern, Beijing, Guangzhou,...
# 32311  [Nashville, Lyon, Marseille, Villejuif, Düssel...
#
#                                            LocationState  \
# 0                         [Massachusetts, Massachusetts]
# 1                                             [New York]
# 2                                             [Maryland]
# 3                                             [Maryland]
# 4                                             [New York]
# ...                                                  ...
# 32307  [California, California, Colorado, Georgia, Il...
# 32308  [Arizona, California, Indiana, Missouri, Rhode...
# 32309  [New York, New South Wales, Queensland, Queens...
# 32310  [Michigan, New South Wales, Victoria, Beijing,...
# 32311                                        [Tennessee]
#
#                                          LocationCountry  \
# 0                         [United States, United States]
# 1                                        [United States]
# 2                                        [United States]
# 3                                        [United States]
# 4                                        [United States]
# ...                                                  ...
# 32307  [United States, United States, United States, ...
# 32308  [United States, United States, United States, ...
# 32309  [United States, Australia, Australia, Australi...
# 32310  [United States, Australia, Australia, China, C...
# 32311  [United States, France, France, France, German...
#
#                                             BriefSummary       nct_id  \
# 0      [The purpose of this study is to investigate t...  NCT02335671
# 1      [The purpose of this study is to see how a new...  NCT02348749
# 2      [Stroke survivors experience severe muscle was...  NCT02347995
# 3      [Retrospective studies indicate that active su...  NCT02346435
# 4      [The aim of this pilot study is to investigate...  NCT02344485
# ...                                                  ...          ...
# 32307  [This study will test an anti-HIV drug (ARV) f...  NCT05406583
# 32308  [The purpose of this study is to measure the b...  NCT05440786
# 32309  [This study is a first-in-human, Phase 1/2, op...  NCT05427812
# 32310  [This first-in-human (FIH) study will evaluate...  NCT05410145
# 32311  [The purpose of this study is to determine rec...  NCT05441501
#
#           downcase_mesh_term
# 0           breast neoplasms
# 1      neuroendocrine tumors
# 2                     stroke
# 3           kidney neoplasms
# 4          parkinson disease
# ...                      ...
# 32307                    hiv
# 32308    neoplasm metastasis
# 32309       multiple myeloma
# 32310            kras p.g12c
# 32311    prostatic neoplasms
#
# [32312 rows x 11 columns]

# %% [markdown]
# ## 1. MAP STUDIES TO MESH TERMS

# %% [markdown]
# - Create a dictionary to map NCT ID's to their mesh_terms

# %%
# Creating a dataframe with nct_id and downcase_mesh_term column from the main data.

data_final = data_final.assign(nct_id = data_final.get('NCTId'),downcase_mesh_term = data_final.get('ConditionMeshTerm'))
df_mesh_ct = data_final.get(['nct_id','downcase_mesh_term'])
df_mesh_ct
# Out:
#             nct_id     downcase_mesh_term
# 0      NCT02335671       breast neoplasms
# 1      NCT02348749  neuroendocrine tumors
# 2      NCT02347995                 stroke
# 3      NCT02346435       kidney neoplasms
# 4      NCT02344485      parkinson disease
# ...            ...                    ...
# 32307  NCT05406583                    hiv
# 32308  NCT05440786    neoplasm metastasis
# 32309  NCT05427812       multiple myeloma
# 32310  NCT05410145            kras p.g12c
# 32311  NCT05441501    prostatic neoplasms
#
# [32312 rows x 2 columns]

# %%
#database_2015 = database[database.get('index').str.contains('/2015')]
#database_2015 = database_2015.assign(nct_id = database_2015.get('NCTId'), downcase_mesh_term = database_2015.get('ConditionMeshTerm'))
#nct_and_mesh = ['nct_id','downcase_mesh_term']
#database_2015 = database_2015.get(nct_and_mesh)
#df_mesh_ct = database_2015
#df_mesh_ct

# %%
#new_2015 = all_data_2015.get(['NCTId','ConditionMeshTerm','Condition'])
#new_2015 = new_2015.assign(ConditionMeshTerm = new_2015.get('ConditionMeshTerm').apply(replace_empty_list))
#new_2022.get('ConditionMeshTerm').iloc[0]
#new_2015 = new_2015.assign(ConditionMeshTerm = new_2015.get('ConditionMeshTerm').apply(pick_first_term))
#empty_in_new_2015_list = new_2015[new_2015.get('ConditionMeshTerm')=='N/A'].index
#new_2015 = new_2015.drop(empty_in_new_2015_list)
#new_2015 = new_2015.assign(nct_id = new_2015.get('NCTId').apply(pick_first_term), downcase_mesh_term = 
                         # new_2015.get('ConditionMeshTerm').apply(lowercase))
#new_2015 = new_2015.get(['nct_id','downcase_mesh_term'])
#df_mesh_ct = new_2015
#new_2015.assign(nct_id = new_2015.get('NCTId').apply(pick_first_term), downcase_mesh_term = new_2015.get('ConditionMeshTerm').apply(pick_first_term))

# %%
#new_jess = new_jess.assign(nct_id = new_jess.get('NCTId'),downcase_mesh_term = new_jess.get('ConditionMeshTerm'))
#df_mesh_ct = new_jess.get(['nct_id','downcase_mesh_term'])

# %% [markdown]
# ### 1.1 CREATING NCT ID TO MESH TERM DICTIONARY

# %%
# Creating dicitionary

from collections import defaultdict
nct_to_mesh_term = defaultdict(set)
for row in df_mesh_ct[['nct_id', 'downcase_mesh_term']].itertuples():
    nct_to_mesh_term[row[1]].add(row[2])

# %%
# Test Case
nct_to_mesh_term['NCT05441501']
# Out:
# {'prostatic neoplasms'}

# %% [markdown]
# Notes:
#
#     Omitted loading of studies.txt since we used the studies alreay in the dataframe "data_final". Also, omitted use of
#     browse_conditions.txt by creating a separate dataframe designed just like browse_conditions.txt.

# %% [markdown]
# ## 2. CONVERT MESH TERMS TO THEIR UNIQUE IDENTIFIERS

# %% [markdown]
# ### 2.1 FIND MESH TERMS AND CODES
#
# - Finding Unique Identifiers for MESH Terms.

# %%
# Function to parse MESH FILE (d2022.bin)

def parse_mesh_file_as_df(filepath):
    import re
    tups = []
    import re
    
    with open(filepath) as fp:
        heading,mesh_nb,ui = None,None,None
        for cnt, line in enumerate(fp):
            if line.startswith('MN ='):
                record_type = re.search(r'MN = (.+)', line).group(1)
                #print('MN: ' + MN)
            elif line.startswith('MH ='):
                name = re.search(r'MH = (.+)', line).group(1).lower()
                #print('name: ' + name)
            elif line.startswith('UI ='):
                ui = re.search(r'UI = (.+)', line).group(1)
                #print('ui: ' + ui)
                tups.append((ui, name, record_type))
    return pd.DataFrame(tups, columns=['ui','name','mesh_number'])

# %%
# Creating dataframe with Mesh Terms and their CUI's from the file d2022.bin

df_mesh=parse_mesh_file_as_df("/Users/sanya/Downloads/d2022.bin")
#print(df_mesh[['ui','name']])
df_mesh
# Out:
#             ui                         name  \
# 0      D000001                   calcimycin
# 1      D000002                      temefos
# 2      D000003                    abattoirs
# 3      D000004       abbreviations as topic
# 4      D000005                      abdomen
# ...        ...                          ...
# 30189  D066310               digital divide
# 30190  D066328             ventral striatum
# 30191  D066329           protein aggregates
# 30192  D066330  printing, three-dimensional
# 30193  D066331      laser-evoked potentials
#
#                                mesh_number
# 0                      D03.633.100.221.173
# 1                      D02.886.300.692.800
# 2                              J03.540.020
# 3                  L01.559.598.400.556.131
# 4                              A01.923.047
# ...                                    ...
# 30189                      L01.143.230.500
# 30190  A08.186.211.200.885.287.249.487.775
# 30191                              D05.875
# 30192                  L01.296.110.150.500
# 30193              G11.561.200.500.400.500
#
# [30194 rows x 3 columns]

# %% [markdown]
# ### 2.2 BUILD MESH TERM TO ID DICITIONARY
#
# - Dictionary to map MESH Terms to their Unique Identifiers

# %%
from collections import defaultdict
mesh_term_to_id = {}

for row in df_mesh[['name','ui']].itertuples():
    mesh_term_to_id[row[1]] = row[2]
    
mesh_term_to_id['ventral striatum']
# Out:
# 'D066328'

# %%
# MeSH terms in CT.gov but not in df_mesh


mesh_missing = set(df_mesh_ct.downcase_mesh_term.values) - set(df_mesh.name.values)
print('mesh terms in CT.gov but not in MeSH official list: %d' % len(mesh_missing))
if len(mesh_missing) <= 2000:
    print(mesh_missing)
# Out:
# mesh terms in CT.gov but not in MeSH official list: 1611
# {'osteoarthritic knee pain', 'hematopoietic steam cell transplantation (hct)', 'autologous hematopoietic stem cell transplant', 'microvascular obstruction', 'heavy drinking and sexual risk behavior', 'survivors of childhood cancer', 'infusion', 'smoking behaviors', 'hospice', 'prosthesis user', 'relationship, marital', 'dent implants', 'transgender', 'cll/sll', 'reduced maximum oxygen uptake due to poor systemic oxygen extraction', 'de-identified eeg and clinical database', 'hematopoietic stem cell transplant', 'digital nerve injury', 'metastatic urothelial cancer', 'injury; muscle, ankle, and foot, multiple', 'meniscus lesion', 'lung cancer', 'thrombolysis', 'metastatic solid tumors', 'kita-kyushu lung cancer antigen 1, human', 'genitourinary syndrome of menopause', 'primary graft failure', 'violence in adolescence', 'radial head fractures', 'chronic rhinosinusitis', 'periprosthetic joint infections', 'oligometastatic malignant solid neoplasm', 'current vaper', 'hematopoietic stem cell transplantations', 'vaso-occlusive crisis', 'kidney transplant recipients', 'firefighter', 'healthy diet', 'gaze tracking', 'locally advanced or metastatic and unresectable hcc', 'newborn morbidity', 'blood flow restriction training', 'coronary artery bypass grafting', 'abortion early', 'intracranial pathology', 't1dm', 'pancreatic cancer', 'kidney pancreas transplant', 'the efficacy of analgesia of laparoscopic tap block in minimally invasive gynecology surgeries', 'labor epidural', 'dog therapy', 'advanced tumors', 'refractory or recurrent hypermutated malignancies', 'cartilage defect', 'efficacy and safety', 'healthcare practitioner stress', 'covid', 'lower respiratory tract illness', 'lower limb amputation', 'oxygen delivery', 'platysma prominence', 'resectable esophageal cancer', 'acute disruption of ankle syndesmosis', 'cardiovascular health', 'adherence, patient', 'episodic memory', 'exercise endurance', 'hemodialysis complication', 'healthy volunteer study', 'clinical trials', 'type 2 diabetes', 'respiratory function loss', 'trauma', 'executive dysfunction', 'extubation', 'image, body', 'supine hypotensive syndrome', 'ovarian serous tumor', 'essential fatty acid deficiency (efad)', 'frail elderly syndrome', 'knee arthroscopy', 'chronobiology', 'child pedestrian safety', 'connecting patients to self-care resources', 'fall', 'nicotine vaping', 'irrigation', 'wound heal', 'focus: to examine acute effects of cbg on anxiety, stress, and cognition', 'early intervention, educational (head start and early head start access and participation)', 'platelet function', 'immune response', 'psychological', 'iud', 'inattention and memory', 'eponychial stent', 'fluid loss', 'ovary; anomaly', 'hereditary neuropathy caused by sord deficiency', 'neck lines', 'dietary habits', 'environmental and genetic factors on lung function', 'medication dosing error', 'head and neck carcinoma', 'thoracic cancer', 'ostheoporosis of the knee', 'fontan physiology', 'growth hormone deficiency (ghd)', 'autoimmune', 'influenza (healthy volunteers)', 'hiv-1-infection', 'sars-cov 2', 'tobacco cessation', 'research awareness', 'race concordant patient-provider relationship', 'subdermal skin tightening', 'nafld', 'cluster detection', 'cardiac surgery', 'nasal surgery', 'radical prostatectomies', 'post-cesarean pain', 'ankle surgery', 'cancer patients', 'n-acetylglutamate synthase (nags) deficiency', 'youth', 'interviews', 'gastrointestinal tolerance', 'physical disability', 'transitional cell cancer of renal pelvis and ureter', 'diet intervention', 'adolescent school connectedness', 'positive thinking', 'tricuspid valve disease', 'limbal stem cell deficiency', 'd3 dopamine receptor', 'abdominal imaging', 'abuse potential', 'digestive health', 'readmission', 'transpulmonary pressure', 'iort-intra-operative radiation therapy', 'muscle', 'prolonged qtc interval', 'perinatal anxiety', 'anterior knee pain', 'educational activities', 'immediate placement of straumann blx implants in m ...

# %%
# Dicitionaries created up until now:
# - nct_to_mesh_term : Look up mesh terms with NCT ID's
# - mesh_term_to_id : Look up mesh Unique Identifiers (ui) with the mesh term

# %% [markdown]
# ## 3. LOAD UMLS CUIS
# - Loading the Concepts and Sources file MRCONSO.RRF from the NLM

# %%
# since the file is big, we need a special function to read in streaming mode and eliminate on the fly
# CUIs that are not in the embeddings


def load_conso(file_name, vocab_keys):
    rows=[]
    cnt=0
    with open(file_name) as fp:  
        for cnt, line in enumerate(fp):
            line=line.strip()
            cols = line.split('|')
            cols[3] = cols[3].lower()
            if cols[0] in vocab_keys:
                rows.append(cols)
            cnt += 1
    
    #print("loaded '%s', %d rows (%s)" % (file_name, len(df), df_mem(df)))
    df = pd.DataFrame(rows, columns=['CUI','SAB','CODE','STR'])
    print("loaded '%s', %d rows (%s)" % (file_name, len(df), df_mem(df)))
    print('processed rows: %d' % cnt)
    return df # Returns dataframe with the 4 Columns mentioned above.

# %%
df_c = load_conso("/Users/sanya/Downloads/MRCONSO_reduced.RRF", vocab_keys)

# df_c : Dataframe with CUI, SAB, CODE AND STR INFO FROM MRCONSO.RRF
# Out:
# loaded '/Users/sanya/Downloads/MRCONSO_reduced.RRF', 2159141 rows (574.7 Mb)
# processed rows: 16857345

# %%
# Test Case
df_c[df_c.CODE=='D014947']
# Out:
#              CUI     SAB     CODE                                  STR
# 967572  C0043250  MSHCZE  D014947                                 rány
# 967583  C0043250     MSH  D014947                               wounds
# 967586  C0043250     MSH  D014947                                wound
# 967613  C0043250  MSHFRE  D014947                               plaies
# 967623  C0043250  MSHITA  D014947                               ferite
# 967636  C0043250  MSHNOR  D014947                                  sår
# 967637  C0043250  MSHPOR  D014947                           ferimentos
# 967638  C0043250  MSHPOR  D014947                              feridas
# 967639  C0043250  MSHPOR  D014947                            ferimento
# 967646  C0043250  MSHPOR  D014947                               ferida
# 967652  C0043250  MSHSPA  D014947                              heridas
# 967656  C0043250  MSHSPA  D014947                               herida
# 967661  C0043251  MSHCZE  D014947                      rány a poranění
# 967662  C0043251  MSHCZE  D014947                               trauma
# 967663  C0043251  MSHDUT  D014947                               trauma
# 967664  C0043251  MSHDUT  D014947                      letsel, wond en
# 967665  C0043251  MSHDUT  D014947                   letsels, wonden en
# 967666  C0043251  MSHDUT  D014947                       wond en letsel
# 967667  C0043251  MSHDUT  D014947                    wonden en letsels
# 967668  C0043251     MSH  D014947                  wounds and injuries
# 967676  C0043251     MSH  D014947                     injuries, wounds
# 967677  C0043251     MSH  D014947                    injury and wounds
# 967678  C0043251     MSH  D014947                    wounds and injury
# 967679  C0043251     MSH  D014947                       wounds, injury
# 967683  C0043251     MSH  D014947                      injuries wounds
# 967684  C0043251     MSH  D014947                      wounds injuries
# 967686  C0043251     MSH  D014947                  injuries and wounds
# 967687  C0043251     MSH  D014947                               trauma
# 967688  C0043251     MSH  D014947                              traumas
# 967692  C0043251     MSH  D014947                           inj wounds
# 967693  C0043251     MSH  D014947                       wounds and inj
# 967694  C0043251     MSH  D014947                           wounds inj
# 967695  C0043251  MSHFIN  D014947                     haavat ja vammat
# 967696  C0043251  MSHFRE  D014947                  plaies et blessures
# 967697  C0043251  MSHFRE  D014947               plaies et traumatismes
# 967698  C0043251  MSHFRE  D014947                         traumatismes
# 967699  C0043251  MSHFRE  D014947       lésions traumatiques et plaies
# 967700  C0043251  MSHFRE  D014947       plaies et lésions traumatiques
# 967701  C0043251  MSHFRE  D014947                               trauma
# 967702  C0043251  MSHGER  D014947              wunden und verletzungen
# 967703  C0043251  MSHGER  D014947                               trauma
# 967704  C0043251  MSHITA  D014947                     ferite e lesioni
# 967705  C0043251  MSHITA  D014947                               trauma
# 967706  C0043251  MSHJPN  D014947  not translated[wounds and injuries]
# 967707  C0043251  MSHNOR  D014947                        sår og skader
# 967708  C0043251  MSHNOR  D014947                               traume
# 967709  C0043251  MSHNOR  D014947                        skader og sår
# 967710  C0043251  MSHPOL  D014947                         rany i urazy
# 967711  C0043251  MSHPOR  D014947                  ferimentos e lesões
# 967712  C0043251  MSHPOR  D014947                              traumas
# 967713  C0043251  MSHPOR  D014947            ferimentos e traumatismos
# 967714  C0043251  MSHPOR  D014947                               trauma
# 967715  C0043251  MSHPOR  D014947                         traumatismos
# 967716  C0043251  MSHPOR  D014947                          traumatismo
# 967717  C0043251  MSHRUS  D014947                        раны и травмы
# 967718  C0043251  MSHRUS  D014947                        rany i travmy
# 967719  C0043251  MSHRUS  D014947                        povrezhdeniia
# 967720  C0043251  MSHRUS  D014947                               travma
# 967721  C0043251  MSHRUS  D014947                          повреждения
# 967722  C0043251  MSHRUS  D014947                               травма
# 967723  C0043251  MSHSCR  D014947                       rane i ozljede
# 967724  C0043251  MSHSPA  D014947                   heridas y lesiones
# 967725  C0043251  MSHSPA  D014947                              traumas
# 967728  C0043251  MSHSPA  D014947                          traumatismo
# 967729  C0043251  MSHSPA  D014947               heridas y traumatismos
# 967730  C0043251  MSHSPA  D014947                               trauma
# 967731  C0043251  MSHSPA  D014947                         traumatismos
# 967732  C0043251  MSHSWE  D014947                       sår och skador

# %%
# Test Case
df_c[df_c.STR=='trauma']
# Out:
#              CUI     SAB     CODE     STR
# 967662  C0043251  MSHCZE  D014947  trauma
# 967663  C0043251  MSHDUT  D014947  trauma
# 967687  C0043251     MSH  D014947  trauma
# 967701  C0043251  MSHFRE  D014947  trauma
# 967703  C0043251  MSHGER  D014947  trauma
# 967705  C0043251  MSHITA  D014947  trauma
# 967714  C0043251  MSHPOR  D014947  trauma
# 967730  C0043251  MSHSPA  D014947  trauma

# %% [markdown]
# ### 3.1 MAP MESH CODES TO CUIS
# - Create dictionary that maps mesh codes to CUI's using the dataframe "dt_c".

# %%
# Dictionary mapping mesh codes to CUI's


from collections import defaultdict
mesh_code_to_cui = defaultdict(set) # used to link a study to CUIs (through mesh codes)

                                   # used later to associate therapeutic area (from their strings) to CUIs
for row in df_c[df_c.SAB=='MSH'][['CODE','CUI']].itertuples():
    code, cui = row[1], row[2]
    if cui in vocab_keys:
        mesh_code_to_cui[code].add(cui)

# %%
#TEST CASE
mesh_code_to_cui['D014947']
# Out:
# {'C0043250', 'C0043251'}

# %% [markdown]
# ### 3.2 MAP STUDIES TO CUIS
# - Create a dictionary of study identifiers to concept CUIs.

# %%
std_to_cuis = defaultdict(set)
imperfect_studies=set()
for idx,(std,terms) in enumerate(nct_to_mesh_term.items()):
    for term in terms:
        mesh_id = mesh_term_to_id.get(term)
        if mesh_id is None:
            #print('mesh term "' + term + \
            #                '" is in CT.gov but not in the official MeSH terms. Ignore term for study %s' % std)
            imperfect_studies.add(std)
            break
        for cui in mesh_code_to_cui[mesh_id]:
            std_to_cuis[std].add(cui)
                
print('removing (imperfect) studies containing at least 1 mesh term not in the official mesh list: %d' % len(imperfect_studies))
for imperfect in imperfect_studies:
    if std_to_cuis.get(imperfect) is not None:
        del std_to_cuis[imperfect]
# Out:
# removing (imperfect) studies containing at least 1 mesh term not in the official mesh list: 2901

# %% [markdown]
# Notes:
#
#     After removing imperfect studies, number of studies remaining are 29501.

# %%
std_to_cuis['NCT02335671'] # breast neoplasms
# Out:
# {'C0006142', 'C0678222', 'C1458155'}

# %% [markdown]
# ## 4. MAP CONCEPT CUIS TO STRINGS
# - Create dictionary mapping CUI's to the STR column that contains a set of descriptions for each CUI.
# - This will be used later to associate therapeutic area (from their strings) to CUIs

# %%
# Creating a dictionary mapping the CUI's to the string column in "df_c"

from collections import defaultdict

cui_to_strings = defaultdict(set)  # a set of descriptions (lowercased) for each CUI (obtained from the STR column)
                                   # used later to associate therapeutic area (from their strings) to CUIs
for row in df_c[['CUI','STR']].itertuples():
    cui, term = row[1], row[2]
    cui_to_strings[cui].add(term)

# %%
cui_to_strings['C1458155']
# breast neoplasms
# Out:
# {'borstkliertumor',
#  'borstneoplasma',
#  'borstneoplasma nao',
#  'borsttumor',
#  'breast neopl',
#  'breast neoplasm',
#  'breast neoplasm diagnosis',
#  'breast neoplasm nos',
#  'breast neoplasms',
#  'breast tumor',
#  'breast tumors',
#  'breast tumour',
#  'breast tumours',
#  'breast--tumors',
#  'brystneoplasmer',
#  'brystsvulster',
#  'brysttumorer',
#  'brösttumörer',
#  'câncer de seio',
#  'câncer do seio',
#  'câncer mamário',
#  'dojka, tumori',
#  'emlő neoplasia',
#  'emlő neoplasia k.m.n.',
#  'emlődaganat',
#  'location of neoplasm of breast',
#  'location of neoplasm of breast (diagnosis)',
#  'mammary neoplasms',
#  'mammary tumor',
#  'mammatumor',
#  'mammatumoren',
#  'mammatumoren, mensch',
#  'molochnoi zhelezy novoobrazovaniia',
#  'neopl breast',
#  'neoplasia da mama',
#  'neoplasia da mama ne',
#  'neoplasia da mama soe',
#  'neoplasia de mama',
#  'neoplasia de mama (trastorno)',
#  'neoplasia de mama neom',
#  'neoplasia mamária',
#  'neoplasia of the breast',
#  'neoplasias da mama',
#  'neoplasias de la mama',
#  'neoplasias de mama',
#  'neoplasias mamarias',
#  'neoplasias mamárias',
#  'neoplasie della mammella',
#  'neoplasm breast',
#  'neoplasm of breast',
#  'neoplasm of breast (diagnosis)',
#  'neoplasm of breast (disorder)',
#  'neoplasm of the breast',
#  'neoplasm, breast',
#  'neoplasma borst',
#  'neoplasma, borst',
#  'neoplasms, breast',
#  'neoplasía de la mama',
#  'neoplasía mamaria',
#  'neubildung der brust',
#  'neubildung der brustdruese',
#  'neubildung der brustdruese nnb',
#  'nisän kasvaimet',
#  'novotvar prsu',
#  'novotvar prsu nos',
#  'nowotwory gruczołu piersiowego',
#  'nowotwory piersi',
#  'nowotwory sutka',
#  'nádory prsu',
#  'prsní nádory',
#  'prsy - nádory',
#  'tumeur du sein',
#  'tumeur mammaire',
#  'tumeur mammaire sai',
#  'tumeurs du sein',
#  'tumor da mama',
#  'tumor de la mama',
#  'tumor de mama',
#  'tumor de seio',
#  'tumor de seno',
#  'tumor of breast',
#  'tumor of the breast',
#  'tumor prsu',
#  'tumor, breast',
#  'tumor, mamma-',
#  'tumore della mammella',
#  'tumore della mammella nas',
#  'tumoren, mamma-',
#  'tumores da mama',
#  'tumores de la mama',
#  'tumores de mama',
#  'tumores de seio',
#  'tumores de seno',
#  'tumores mamarios',
#  'tumores mamários',
#  'tumori del seno',
#  'tumori della mammella',
#  'tumors, breast',
#  'tumour of breast',
#  'tumours of the breast',
#  'молочной железы новообразования',
#  'новообразование грудной железы',
#  'новообразование молочной железы',
#  'новообразование молочной железы бду',
#  '乳がん',
#  '乳ガン',
#  '乳房がん',
#  '乳房の新生物',
#  '乳房新生物',
#  '乳房新生物ｎｏｓ',
#  '乳房腫瘍',
#  '乳癌',
#  '乳腺mucocele-like tumor',
#  '乳腺悪性腫瘍',
#  '乳腺癌',
#  '乳腺腫瘍(ヒト)',
#  '乳腺腫瘍-ヒト',
#  '乳腺腫瘍-人間',
#  '유방 신생물',
#  '유방 신생물 nos',
#  'ﾆｭｳﾎﾞｳｼﾝｾｲﾌﾞﾂ',
#  'ﾆｭｳﾎﾞｳｼﾝｾｲﾌﾞﾂnos',
#  'ﾆｭｳﾎﾞｳﾉｼﾝｾｲﾌﾞﾂ'}

# %% [markdown]
# ### 4.1 GET STUDY TERMS FROM THE STUDY ID

# %%
# Creating function to retrieve the CUI terms in a study from the dictionary "std_to_cuis"

def get_study_terms(std):
    #  mesh terms -> CUIs (UMLS) -> 
    # -> CUI terms from MRCONSO.RRF (all strings for the CUI)
    cuis = std_to_cuis.get(std)
    terms = set()
    if cuis is None:
        return terms
    for cui in cuis:
        terms.update(cui_to_strings[cui])
    return terms

# %%
# test case
list(get_study_terms('NCT02347995'))[:5]
#stroke
# Out:
# ['cerebrovaskularni incident',
#  'accidente cerebrovascolare nas',
#  'stroke unspecified',
#  'cerebrovascular accident',
#  'stroke, cerebrovascular']

# %% [markdown]
# ## 5. Manually Associate Therapeutic Areas to UMLS Concepts (CUIs)

# %% [markdown]
# ### 5.1 CREATING FUNCTIONS
# - Create a function (any_term_in_strings) to return a boolean value if our input contains a string.
# - Create a function (find_cuis_for_terms) to return the set of CUI's whose terms match a list of terms that we input.

# %%
def any_term_in_strings(term_list, strings):
    """
    Returns True if any term of term_list is in strings.
    Args:
    - term_list: list of strings
    - strings: other list of strings
    """
    for term in term_list:
        term_ok=False
        for string in strings:
            if term in string:
                #print('  term "%s" ok! in string: %s' % (term,string))
                return True
    return False

if False: # test
    any_term_in_strings(['virus','viral'], {'aa viral', 'bb'})

def find_cuis_for_terms(term_lists, exclude_terms=None):
    """
    Finds the set of CUIs whose terms match a list of terms.
    Args:
    - term_lists: list of list of terms: for each of the term_list in term_lists, 
      at least one term must be in at least one of the strings. Thus it's an OR 
      inside the term_list, but an AND between term_list.
    - exclude_terms: the CUI is rejected if contains one of these terms.
    Returns:
    - a set of CUIs as a set of strings.
    """
    cuis=set()
    cnt=0
    for cui,strings in cui_to_strings.items():
        # if any excluded term is in any strings, reject this cui
        if exclude_terms is not None:
            excluded = False
            for ex_term in exclude_terms:
                for string in strings:
                    if ex_term in string:
                        excluded = True
                        break
                if excluded:
                    break
            if excluded:
                #print('cui %s excluded. Strings: %s' % (cui, str(strings)))
                continue
                
        # process the term_lists
        cui_ok = True
        for term_list in term_lists:
            #print('searching term_list "%s"' % (term_list))
            if not any_term_in_strings(term_list, strings):
                #print('term list "%s" does not match strings "%s"' % (term_list, strings))
                cui_ok = False
                break
            #else:
            #    #print('term list "%s" matches strings "%s"' % (term_list, strings))
            #    cnt+=1
            #    if cnt == 100:
            #        return
                
        if cui_ok:
            # THIS IS THE LINE TO UNCOMMENT TO DEBUG CUIs
            #print('accepted cui "%s" that corresponds to strings "%s"\n' % (cui, str(strings)))
            cuis.add(cui)
    return cuis

# %% [markdown]
# ### 5.2 MANUALLY ASSOCIATE CUI'S TO THERAPEUTIC AREA
#
# - Manually implement the function "find_cuis_for_terms" to retrieve cui's for various terms.
# - Manually associate the output of the function "find_cuis_for_terms" to Therapeutic Areas.

# %%
#


cardiology_cuis = find_cuis_for_terms([['cardiolog', 'cardiovascul']])
#dental_cuis = find_cuis_for_terms([['dental', ]], exclude_terms=['accidental', 'incidental', 'occidental', 'osteodental'])
#dental_cuis = find_cuis_for_terms([['caries', 'cavity', 'cavities', 'orthodon', 'endodon',]]) # worse!
dental_cuis = find_cuis_for_terms([['tooth cavit', 'caries', 'cavities']], 
                                  exclude_terms=['peccaries', 'cotyloid cavities', 'nasal cavities', 'cavities, glenoid', 'cavities paranasal',
                                                 'pleural cavities', 'cavities, pleural', 'pericardial cavities', 'cavities pelvic',
                                                 'cavities uterine', 'abdominal cavities', 'cavities, tympanic', 'body cavities'])
dermatology_cuis = find_cuis_for_terms([['dermatol', ]]) # 'skin' adds too many matches in other contexts
device_cuis = find_cuis_for_terms([['device', ]])
environ_cuis = find_cuis_for_terms([['environmental', 'environments', 'pollut']])
endocrinology_cuis = find_cuis_for_terms([['endocrinol', ]])
family_med_cuis = find_cuis_for_terms([['family medicine', ]])
gastro_cuis = find_cuis_for_terms([['gastroentero', ]])
genetic_cuis = find_cuis_for_terms([['geneti', ], ['diseas']])
volunteer_cuis = find_cuis_for_terms([['volunteer', ]]) # difficult. Other contexts than health
hematology_cuis = find_cuis_for_terms([['hematol', ]], exclude_terms=['non-hemato'])
#hepatology_cuis = find_cuis_for_terms([['hepatol', 'hepatic']])
#hepatology_cuis = find_cuis_for_terms([['liver']])
hepatology_cuis = find_cuis_for_terms([['hepatitis']]) # needs to be refined. Might too restrictive but liver/hepatol match too much
immunology_cuis = find_cuis_for_terms([['immunolog']])
infect_cuis=find_cuis_for_terms([['infectious', 'infected', 'infection'], ['disease']])
intern_cuis=find_cuis_for_terms([['intern'],['medicin']])
muskuloskel_cuis=find_cuis_for_terms([['musculoskelet']])
nephrology_cuis=find_cuis_for_terms([['nephrolog']])
neurology_cuis=find_cuis_for_terms([['neurolog']])
nutrition_cuis=find_cuis_for_terms([['nutrition', 'body weight', 'weight reduc', 'weight gain', 'overweight']])
obstetrics_cuis=find_cuis_for_terms([['obstetri', 'gynecol']])
oncology_cuis = find_cuis_for_terms([['oncolog', 'cancer']])
occupdisease_cuis = find_cuis_for_terms([['occupational disease']])
ophtalmo_cuis = find_cuis_for_terms([['ophthalmol', 'eye']])
orthopedics_cuis = find_cuis_for_terms([['orthopedi']])
otorino_cuis = find_cuis_for_terms([['otolaryngol']])
pediatrics_cuis = find_cuis_for_terms([['pediatr', 'neonat']])
parasitic_cuis = find_cuis_for_terms([['parasit'],['disease']])
pharmacol_toxicol_cuis = find_cuis_for_terms([['pharmacol', 'toxicol']])
#podiatrics_cuis = find_cuis_for_terms([['podiat', 'foot diseases', 'foot injur']]) # podiatry not found in embeddings, although in UMLS
podiatrics_cuis = find_cuis_for_terms([['podiat']]) # including foot diseases/injur make it match dental studies
psy_cuis = find_cuis_for_terms([['psychiatr', 'psycholog']])
pulmon_cuis = find_cuis_for_terms([['pulmonar', 'respirat'], ['diseas']])
rare_cuis = find_cuis_for_terms([['orphan drug', ]])# C0178786 orphan disease/drug
                                                    # C0178604 drug design/synthesis/production
                                                    # C0013232 Drugs, Orphan        --> THE ONLY ONE PRESENT IN EMBEDDINGS :(
                                                    # C0920627 Orphan Diseases
                                                    # C0029308 Orphan Drug Production
                                                    # C0599036 unprofitable drug development
                                                    # C0678236 Rare Diseases
rheumatology_cuis = find_cuis_for_terms([['rheumat', ]]) # C0035452 (Rheumatology specialty) badly missing + should we limit to 'rheumatolog' ?
sleep_cuis = find_cuis_for_terms([['sleep', ]])
symptoms_cuis = find_cuis_for_terms([['general manifestation of disorders', ]]) # matches only C1457887: symptoms
traume_cuis = find_cuis_for_terms([['traumas', ]]) # seems more focused than 'trauma' and avoids 'non-trauma' and 'nontrauma' strings
urology_cuis = find_cuis_for_terms([['urology', ]])
vaccine_cuis = find_cuis_for_terms([['vaccine', ]])

# Creating dictionary associating the cui terms retrieved above to Therapeutic Areas

areas = {
    'Cardiology/Vascular Diseases' :       cardiology_cuis,
    'Dental and Oral Health' :             dental_cuis,
    'Dermatology' :                        dermatology_cuis,
    'Devices' :                            device_cuis,
    'Disorders of Environmental Origin' :  environ_cuis,
    'Endocrinology' :                      endocrinology_cuis,
    'Family Medicine' :                    family_med_cuis,
    'Gastroenterology' :                   gastro_cuis,
    'Genetic Disease' :                    genetic_cuis,
    'Healthy Volunteers' :                 volunteer_cuis,
    'Hematology' :                         hematology_cuis,
    'Hepatology' :                         hepatology_cuis,
    'Immunology' :                         immunology_cuis,
    'Infections and Infectious Diseases' : infect_cuis,
    'Internal Medicine' :                  intern_cuis,
    'Musculoskeletal' :                    muskuloskel_cuis,
    'Nephrology' :                         nephrology_cuis,
    'Neurology' :                          neurology_cuis,
    'Nutrition and Weight Loss' :          nutrition_cuis,
    'Obstetrics/Gynecology' :              obstetrics_cuis,
    'Oncology' :                           oncology_cuis,
    'Occupational Diseases' :              occupdisease_cuis,
    'Ophthalmology' :                      ophtalmo_cuis,
    'Orthopedics/Orthopedic Surgery' :     orthopedics_cuis,
    'Otolaryngology' :                     otorino_cuis,
    'Pediatrics/Neonatology' :             pediatrics_cuis,
    'Parasitic Diseases' :                 parasitic_cuis,
    'Pharmacology/Toxicology' :            pharmacol_toxicol_cuis,
    'Podiatry' :                           podiatrics_cuis,
    'Psychiatry/Psychology' :              psy_cuis,
    'Pulmonary/Respiratory Diseases' :     pulmon_cuis,
    'Rare Diseases and Disorders' :        rare_cuis,
    'Rheumatology' :                       rheumatology_cuis,
    'Sleep' :                              sleep_cuis,
    'Symptoms and General Pathology' :     symptoms_cuis,
    'Trauma' :                             traume_cuis,
    'Urology' :                            urology_cuis,
    'Vaccines' :                           vaccine_cuis,
}

# %% [markdown]
# # 6. Match Studies with Therapeutic Areas using Concept Embeddings
# - Create function to find the therapeutic areas having the closest concepts to those of a given study.
# - We will be using the dictionaries created earlier for our functions.

# %%
# Creating function to find the therapeutic areas having the closest concepts to those of a given study

def find_best_areas(std):
    """
    Finds the therapeutic areas having the closest concepts to those of a given study
    Args:
    - std: study identifier
    Returns:
    - the study terms for debugging purposes
    - a list of 5 tuple2 containing the area and the similarity score with the study
      in similarity decreasing order
    """
    std_cuis = std_to_cuis[std]
    sims, area_list = [], []
    for area, cuis in areas.items():
        if len(std_cuis) == 0:
            raise Exception('no cuis for std %s' % std)
        sims.append(w2v.n_similarity(std_cuis, cuis))
        area_list.append(area)
    indices = list(reversed(np.argsort(sims)))
    best_areas = np.array(area_list)[indices][:5]
    best_sims = np.array(sims)[indices][:5]
    return get_study_terms(std), list(zip(best_areas,best_sims))

# %%
find_best_areas('NCT02347995')
# Out:
# ({'acc cerebrovascular/apoplejia',
#   'accident - cerebrovascular',
#   'accident cerebrovasculair',
#   'accident cerebrovascular',
#   'accident cérébro-vasculaire',
#   'accident cérébrovasculaire',
#   'accident cérébrovasculaire sai',
#   'accident ischémique cérébral',
#   'accident vasculaire cerebral',
#   'accident vasculaire cérébral',
#   'accident, cerebrovasculair',
#   'accident, cérébrovasculaire',
#   'accident; cerebraal',
#   'accident; cerebral',
#   'accident; cerebrovasculair',
#   'accident; cerebrovascular',
#   'accidente cerebral vascular',
#   'accidente cerebrovascolare',
#   'accidente cerebrovascolare nas',
#   'accidente cerebrovascular',
#   'accidente cerebrovascular (concepto no activo)',
#   'accidente cerebrovascular (trastorno)',
#   'accidente cerebrovascular neom',
#   'accidente cerebrovascular, no especificado',
#   'accidente cerebrovascular, no especificado (trastorno)',
#   'accidente cerebrovascular, sai',
#   'accidente cerebrovascular, sai (trastorno)',
#   'accidente vascular cerebral',
#   'accidente vascular del cerebro',
#   'accidente vascular encefálico',
#   'accidentes cerebrovasculares',
#   'acidente cerebral vascular',
#   'acidente cerebrovascular',
#   'acidente vascular cerebral',
#   'acidente vascular cerebral (avc)',
#   'acidente vascular cerebral ne',
#   'acidente vascular cerebral soe',
#   'acidente vascular do cérebro',
#   'acidente vascular encefálico',
#   'acidente/doenca cerebrovascular',
#   'acidentes cerebrais vasculares',
#   'acidentes cerebrovasculares',
#   'acidentes vasculares cerebrais',
#   'acv',
#   'acv, sai',
#   'agyergorcs/agyverzes',
#   'aivohalvaus',
#   'aivohalvaus/ aivoverenkierron hairio',
#   'apoplejía',
#   'apoplejía cerebral',
#   'apoplejía cerebrovascular',
#   'apopleksi',
#   'apopleksi/cerebrovaskulaer katastr',
#   'apopleksiia mozga',
#   'apopleksja',
#   'apoplektischer insult',
#   'apoplessia',
#   'apoplessia cerebrale',
#   'apoplessia cerebrovascolare',
#   'apoplex (ex tia)',
#   'apoplexi',
#   'apoplexia',
#   'apoplexia cerebral',
#   'apoplexia cerebrovascular',
#   'apoplexie',
#   'apoplexie cérébrale',
#   'apoplexie; beroerte',
#   'apoplexie; cerebraal',
#   'apoplexy',
#   'apoplexy, cerebral',
#   'apoplexy, cerebrovascular',
#   'apoplexy, nos',
#   'apoplexy; cerebral',
#   'apoplexy; stroke',
#   'atakea/ezbehar baskular burmuinetakoa',
#   'ataque',
#   'ataque cerebral',
#   'ataque cerebrovascular',
#   "attaque d'apoplexie",
#   'avc',
#   'avc (accident vasculaire cérébral)',
#   'ave',
#   'beroerte',
#   'beroerte, niet gespecificeerd als bloeding of infarct',
#   'beroerte; apoplexie',
#   'brain attack',
#   'brain vascular accident',
#   'brain vascular accidents',
#   'cerebraal; accident',
#   'cerebraal; apoplexie',
#   'cerebral apoplexy',
#   'cerebral apoplexy, nos',
#   'cerebral stroke',
#   'cerebral strokes',
#   'cerebral vascular accident',
#   'cerebral vascular events',
#   'cerebral; accident',
#   'cerebral; apoplexy',
#   'cerebrale beroerte',
#   'cerebraovascularis insultus',
#   'cerebrovasc accid (cva)',
#   'cerebrovasculair accident',
#   'cerebrovasculair accident (cva)',
#   'cerebrovasculair accident nao',
#   'cerebrovasculair; accident',
#   'cerebrovasculaire apoplexie',
#   'cerebrovascular accident',
#   'cerebrovascular accident (disorder)',
#   'cerebrovascular accident (disorder) [ambiguous]',
#   'cerebrovascular accident nos',
#   'cerebrovascular accident, nos',
#   'cerebrovascular accidents',
#   'cerebrovascular apoplexy',
#   'cerebrovascular stroke',
#   'cerebrovascular strokes',
#   'cerebrovascular; accident',
#   'cerebrovascularis esemény',
#   'cerebrovascularis insultus k.m.n.',
#   'cerebrovaskularni incident',
#   'cerebrovaskulär apoplexi',
#   'cerebrovaskulär händelse',
#   'cerebrovaskulær hendelse',
#   'cmp',
#   'colpo/accidente cerebrovascolare',
#   'cva',
#   'cva (cerebral vascular accident)',
#   'cva (cerebrovascular accident)',
#   'cva (incidente cerebrovascolare)',
#   'cva - cerebrovascular accident',
#   'cva - cerebrovascular accident (& unspecified [& stroke])',
#   'cva - cerebrovascular accident (& unspecified [& stroke]) (disorder)',
#   'cva - cerebrovascular accident unspecified',
#   'cva nos',
#   'cva unspecified',
#   'cva, nos',
#   'cvas (cerebrovascular accident)',
#   'cévní mozková příhoda',
#   'cévní mozková příhoda nos',
#   'erua moxi',
#   'hjarnslag/cerebrovaskular skada',
#   'hjerneslag',
#   'hjerneslag/cerebrovask katastrofe',
#   'hjärnattack',
#   'icto cerebral',
#   'ictus',
#   'ictus cerebral',
#   'ictus cerebrale',
#   'iktus',
#   'incidente cerebrovascolare',
#   'incidente vascolare cerebrale',
#   'incydent naczyniowo-mózgowy',
#   "insul't",
#   "insul't tserebrovaskuliarnyi",
#   'mozková mrtvice',
#   'mozková příhoda',
#   'moždana kap',
#   'moždani udar',
#   'ostry udar mózgu',
#   'schlaganfall',
#   'schlaganfall nnb',
#   'schlaganfall, nicht als blutung oder infarkt bezeichnet',
#   'slag',
#   'slaganfall',
#   'stroke',
#   'stroke (cerebrum)',
#   'stroke and cerebrovascular accident unspecified',
#   'stroke and cerebrovascular accident unspecified (disorder)',
#   'stroke cerebral',
#   'stroke nos',
#   'stroke nos (disorder)',
#   'stroke syndrome',
#   'stroke unspecified',
#   'stroke, cerebral',
#   'stroke, cerebrovascular',
#   'stroke, neurological',
#   'stroke, nos',
#   'stroke, not specified as haemorrhage or infarction',
#   'stroke, not specified as hemorrhage or infarction',
#   'stroke/cerebrovasc accident',
#   'stroke/cerebrovascular accident',
#   'stroke/cva',
#   'stroke/cva - undefined',
#   'stroke/cva unspecified',
#   'stroke; apoplectic',
#   'strokes',
#   'strokes, cerebral',
#   'strokes, cerebrovascular',
#   'tserebrovaskuliarnaia apopleksiia',
#   'udar mózgowy',
#   'udar mózgu',
#   'undetermined stroke',
#   'vasculair accident van de hersenen',
#   'vascular accident, brain',
#   'vascular accidents, brain',
#   'vascular brain accident',
#   'vascular cerebral accident',
#   'vaskulärer insult des gehirns',
#   'zerebraler schlaganfall',
#   'zerebrovaskuläre apoplexie',
#   'zerebrovaskulärer insult',
#   'апоплексия',
#   'апоплексия мозга',
#   'инсульт',
#   'инсульт цереброваскулярный',
#   'онмк',
#   'острое нарушение мозгового кровообращения',
#   'острое нарушение мозгового кровообращения, бду',
#   'цереброваскулярная апоплексия',
#   'ストローク',
#   '卒中',
#   '卒中発作',
#   '後頭蓋卒中',
#   '発作症候群',
#   '脳クリーゼ',
#   '脳出血発作症候群',
#   '脳卒中',
#   '脳卒中発作',
#   '脳発症',
#   '脳血管発作',
#   '脳血管発作ｎｏｓ',
#   '血管発作-脳血管',
#   '뇌졸중',
#   '뇌혈관 사고',
#   '뇌혈관 사고 nos',
#   '졸중',
#   '출혈 또는 경색증으로 명시되지 않은 뇌중풍',
#   'ｿｯﾁｭｳ',
#   'ﾉｳｹｯｶﾝﾎｯｻ',
#   'ﾉｳｹｯｶﾝﾎｯｻnos',
#   'ﾉｳｿｯﾁｭｳ'},
#  [('Neurology', 0.4360425),
#   ('Cardiology/Vascular Diseases', 0.42245397),
#   ('Trauma', 0.3741505),
#   ('Nephrology', 0.3043946),
#   ('Sleep', 0.3010249)])

# %%
# Creating function to find therapeutic areas for a given number of studies.


def classify_studies(nb_studies):
    """
    Finds therapeutic areas for a given number of studies. Prints a basic summary 
    of the results
    Args:
    - nb_studies: number of studies to consider.
    Returns:
    - a dictionary indexed by area whose value is a list of 3-tuples containing:
      - study identifier
      - study strings (see get_study_terms()) for evaluation
      - the list of closest areas order with their similarity score, the first one being
        the corresponding dictionary key.
    """
    from collections import defaultdict
    # stds_by_area: key: area, value: list( (study_id, list(study_term), list( (area,similarity) )) )
    stds_by_area = defaultdict(list) 
    
    for cnt,std in enumerate(list(std_to_cuis.keys())[:nb_studies]):
        std_terms, areas_sim = find_best_areas(std)
        area = areas_sim[0][0]
        if area not in stds_by_area.keys():
            print("study found for area '%s' after analyzing %d studies" % (area, cnt+1))
        stds_by_area[area].append((std, std_terms, areas_sim))

    # sort results by number of studies in each area, just to print a summary of results
    res_areas, res_lens = [], []
    for area,ranks_list in stds_by_area.items():
        res_areas.append(area)
        res_lens.append(len(ranks_list))
    res_areas, res_lens = np.array(res_areas), np.array(res_lens)
    indices = list(reversed(np.argsort(res_lens)))
    sorted_areas = np.array(res_areas)[indices]
    sorted_lens = np.array(res_lens)[indices]
    areas_results = list(zip(sorted_areas,sorted_lens))
    print('%d studies in %d areas' % (nb_studies, len(areas_results)))
    for res in areas_results:
        print('%s: %d' %(res[0], res[1]))
        
    return stds_by_area

# %% [markdown]
# ## 7. RESULTS

# %%
# Classifying all studies available

studies_by_area = classify_studies(29501)
# Out:
# study found for area 'Oncology' after analyzing 1 studies
# study found for area 'Neurology' after analyzing 3 studies
# study found for area 'Occupational Diseases' after analyzing 5 studies
# study found for area 'Cardiology/Vascular Diseases' after analyzing 7 studies
# study found for area 'Psychiatry/Psychology' after analyzing 9 studies
# study found for area 'Ophthalmology' after analyzing 20 studies
# study found for area 'Nutrition and Weight Loss' after analyzing 26 studies
# study found for area 'Pulmonary/Respiratory Diseases' after analyzing 28 studies
# study found for area 'Immunology' after analyzing 29 studies
# study found for area 'Infections and Infectious Diseases' after analyzing 37 studies
# study found for area 'Parasitic Diseases' after analyzing 38 studies
# study found for area 'Genetic Disease' after analyzing 41 studies
# study found for area 'Rheumatology' after analyzing 59 studies
# study found for area 'Orthopedics/Orthopedic Surgery' after analyzing 63 studies
# study found for area 'Trauma' after analyzing 64 studies
# study found for area 'Obstetrics/Gynecology' after analyzing 82 studies
# study found for area 'Vaccines' after analyzing 85 studies
# study found for area 'Musculoskeletal' after analyzing 86 studies
# study found for area 'Gastroenterology' after analyzing 109 studies
# study found for area 'Sleep' after analyzing 140 studies
# study found for area 'Nephrology' after analyzing 145 studies
# study found for area 'Dermatology' after analyzing 148 studies
# study found for area 'Symptoms and General Pathology' after analyzing 260 studies
# study found for area 'Pediatrics/Neonatology' after analyzing 372 studies
# study found for area 'Dental and Oral Health' after analyzing 484 studies
# study found for area 'Hematology' after analyzing 487 studies
# study found for area 'Endocrinology' after analyzing 531 studies
# study found for area 'Disorders of Environmental Origin' after analyzing 624 studies
# study found for area 'Hepatology' after analyzing 704 studies
# study found for area 'Devices' after analyzing 921 studies
# study found for area 'Healthy Volunteers' after analyzing 1040 studies
# study found for area 'Internal Medicine' after analyzing 1066 studies
# study found for area 'Urology' after analyzing 1421 studies
# study found for area 'Pharmacology/Toxicology' after analyzing 1883 studies
# study found for area 'Rare Diseases and Disorders' after analyzing 13100 studies
# study found for area 'Family Medicine' after analyzing 15886 studies
# 29501 studies in 36 areas
# Oncology: 9458
# Psychiatry/Psychology: 1875
# Cardiology/Vascular Diseases: 1616
# Rheumatology: 1473
# Genetic Disease: 1231
# Trauma: 1187
# Neurology: 1113
# Nutrition and Weight Loss: 1075
# Pulmonary/Respiratory Diseases: 859
# Ophthalmology: 858
# Occupational Diseases: 728
# Sleep: 664
# Infections and Infectious Diseases: 640
# Musculoskeletal: 586
# Parasitic Diseases: 524
# Immunology: 459
# Obstetrics/Gynecology: 395
# Nephrology: 358
# Hepatology: 332
# Gastroenterology: 188
# Orthopedics/Orthopedic Surgery: 179
# Pharmacology/Toxicology: 179
# Dermatology: 177
# Symptoms and General Pathology: 153
# Dental and Oral Health: 130
# Pediatrics/Neonatology: 110
# Endocrinology: 107
# Disorders of Environmental Origin: 99
# Vaccines: 92
# Internal Medicine: 72
# Hematology: 54
# Devices: 44
# Urology: 16
# Rare Diseases and Disorders: 5
# Healthy Volunteers: 2
# Family Medicine: 2

# %%
# print results for 5 studies for each found therapeutic area
for area,results_list in studies_by_area.items():
    print('======= %s ==========' % area)
    for results in results_list[:5]:
        std, terms, ranks = results
        print('study: %s' % std)
        print('terms: %s' % str(terms))
        print('ranks: %s' % str(ranks))
        print()
# Out:
# ======= Oncology ==========
# study: NCT02335671
# terms: {'breast carcinomas', 'carcinoma of the breast', 'ﾆｭｳｶﾞﾝ', '乳腺腫瘍(ヒト)', 'carcinomas de mama', 'neoplasia da mama soe', 'ca de mama', '乳癌', 'tumore della mammella nas', 'malignant breast neoplasm', 'breast carcinoma', 'tumors, breast', 'cancer de seno', 'tumori della mammella', 'maligne neopl borsten', '유방의 악성신생물', 'ca - carcinoma of breast', 'ca da mama', 'nowotwory sutka', 'neoplasía mamaria', 'carcinoma of breast nos (disorder)', 'brusttumor boesartig', 'carcinoma da mama', 'ﾆｭｳﾎﾞｳﾉｼﾝｾｲﾌﾞﾂ', 'neoplasie della mammella', 'cáncer de mama, estadio no especificado', 'ondartet svulst mamma', 'malignant neoplasm breast', 'câncer de seio', '乳腺mucocele-like tumor', 'borstkliertumor', 'tumore della mammella', 'carcinomas da mama', 'rakovina prsu', '[x]malignant neoplasm of breast', '乳腺悪性腫瘍', 'карцинома грудной железы', 'tumor maligno de mama', 'borstneoplasma nao', 'breast, carcinoma', 'neoplasie maligne della mammella', '악성 유방 신생물', 'cancro da mama', 'neopl breast', '乳腺腫瘍-ヒト', 'maligne neoplasma van mamma', 'tumores de la mama', 'câncer de mama em estágio não especificado', 'neoplasms, breast', '乳房の新生物', 'breast tumor malignant', '乳癌、病期不明', 'tumores da mama', 'malignant tumor of breast (disorder)', 'borstcarcinoom nao', 'molochnoi zhelezy novoobrazovaniia', 'mammatumor', 'cancro della mammella nas', 'tumores malignos de la mama', 'tumor maligno de mama (trastorno)', 'brystkreft', 'breast malignant neoplasm', 'malignant tumour of breast', 'prsní nádory', 'neoplasia de mama (trastorno)', 'tumor maligno da mama', 'breast neoplasm', 'boesartige neubildung der brust', 'tumore maligno della mammella', 'breast, unspecified', 'carcinome du sein', '유방 암종', 'maligne neoplasma van mamma, niet gespecificeerd', 'carcinome mammaire', 'cancer of the breast', 'ondartet svulst bryster', 'cancer, breast', 'карцинома молочной железы', 'tumor maligno de la mama', 'tumor de la mama', '乳腺癌', 'carcinoma mammario nas', 'emlő neoplasia', 'mammary neoplasms', '[x]malignant neoplasm/breast', 'рак молочной железы бду', 'brystsvulster', 'borsttumor', 'tumores mamarios', 'nowotwory piersi', 'tumeur mammaire', 'ca borst', '[x]neoplasia maligna de mama', 'maligní nádorové onemocnění prsu nos', 'breast cancer', 'malignant breast tumor', 'breast carcinoma nos', 'tumor, mamma-', 'malignant neoplasm/breast', 'ｱｸｾｲﾆｭｳﾎﾞｳｼｭﾖｳ', 'carcinoma of breast (diagnosis)', 'neoplasm of breast (diagnosis)', 'mammatumoren, mensch', 'cánceres de mama', 'neoplasia da mama', 'breast neoplasm diagnosis', 'emlőrák k.m.n.', 'maligní nádorové onemocnění prsu blíže neurčeného stadia', 'cancro da mama estádio ne', 'carcinoma da mama soe', 'злокачественная опухоль молочной железы', 'emlődaganat', 'neoplasia mamária', 'sartan hashad', 'breast tumors', 'borstneoplasma', 'neoplasia maligna da mama', '乳ガン', 'carcinoma de mama neom', 'malignant neoplasm of breast', 'tumour of breast', '병기 상세 불명의 유방암', 'malignus mell tumor', 'carcinoma of breast nos', 'rintarauhasen pahanlaatuinen kasvain', 'carcinoma of breast (disorder)', 'breast malignant tumors', 'ka brust', 'tumeur mammaire sai', 'neoplasias de la mama', 'malignant neoplasm of breast, unspecified', 'boesartige neubildung: brustdruese, nicht naeher bezeichnet', 'cancer, mammary', 'cancer du sein stade non précisé', 'malignant tumor of breast', 'malignant neoplasm of breast, unspecified part', 'cáncer de mama neom', 'cáncer de mama', '乳房新生物ｎｏｓ', 'cânceres de mama', 'brustkrebs nnb', 'tumoren, mamma-', 'tumori del seno', 'tumor de seio', 'malignus emlődaganat', 'breast cancers', 'neoplasm of the breast', 'breast cancer nos', 'ca - breast cancer', 'brustkrebs, stadium nicht spezifiziert', 'breast tumours', 'breast malignant tumor', 'malignant neoplasms of breast (c50)', 'karcinom prsu', 'carcinoma de mama, sai', 'neubildung der brust', 'brösttumörer', 'carcinoma mamario', 'emlő carcinoma', '유방 신생물 nos', 'neoplasía de la mama', 'ﾆｭｳｶﾞﾝﾋﾞｮｳｷﾌﾒｲ', '상세불명 유방의 악성신생물', 'karcinom prsu nos', 'câncer de mama', 'carcinoma of breast', 'ca 유방', 'karzinom  ...
# ranks: [('Oncology', 0.6013633), ('Endocrinology', 0.25915164), ('Genetic Disease', 0.20486312), ('Immunology', 0.19724885), ('Obstetrics/Gynecology', 0.17809257)]
#
# study: NCT02348749
# terms: {'tumor neuroendócrino', 'tumoren, neuro-endocriene', 'ｼﾝｹｲﾅｲﾌﾞﾝﾋﾟｼｭﾖｳ', 'нейроэндокринные опухоли', 'neiroendokrinnye novoobrazovaniia', 'neoplasia neuroendocrina (anomalía morfológica)', 'tumor, neuro-endocriene', 'neoplasms neuroendocrine', 'tumores neuroendocrinos', 'tumeurs neuroendocriniennes', '신경 내분비 종양', 'nevroendokrine svulster', 'нейроэндокринные новообразования', 'нейроэндокринный рак', 'нейроэндокринная опухоль', 'tumor neuroendocrino (trastorno)', 'neuroendokriiniset kasvaimet', 'tumeur neuroendocrinienne', 'neuroendokrina tumörer', 'nen', '神経内分泌腫瘍', 'tumor neuroendocrino (anomalía morfológica)', 'neuroendocrin tumor', 'ｼﾝｹｲﾅｲﾌﾞﾝﾋﾟﾂｼｭﾖｳ', 'neuroendokrinní nádor', 'neuroendocrine tumors', 'neuroendocrine tumor', 'neuroendocrine tumor (morphologic abnormality)', 'tumeurs neuroendocrines', 'tumeur neuroendocrine', 'neuroendokriner tumor', 'tumor, neuroendocrine', 'tumors, neuroendocrine', 'neuroendocrine tumours', 'neiroendokrinnye opukholi', 'neuroendokrini tumori', 'neuroendokrinní nádory', 'tumeurs neuro-endocriniennes', 'tumori neuroendocrini', 'neuroendocrine neoplasm', 'neuroendocrine tumour', 'tumore neuroendocrino', 'neuroendocrine neoplasia', 'nowotwory neuroendokrynne', 'neuroendocrine neoplasm (morphologic abnormality)', 'tumores neuroendócrinos', 'neuro-endocriene tumor', 'neuroendocrine tumor nos', 'neuro-endocriene tumoren', 'neoplasia neuroendocrina', 'neuroendocrine tumor (diagnosis)', 'neuroendokrine tumoren', 'nevroendokrine tumorer', 'tumor neuroendócrino (trastorno)', 'neuroendocrine tumor (disorder)', 'tumeurs neuro-endocrines [neuroendocrine tumors] (m0027590)', 'tumor neuroendocrino'}
# ranks: [('Oncology', 0.74243313), ('Endocrinology', 0.44491655), ('Gastroenterology', 0.391802), ('Rheumatology', 0.38045514), ('Genetic Disease', 0.35673776)]
#
# study: NCT02346435
# terms: {'gezwel, nier-', 'renal cell cancer', 'neoplasm of kidney (disorder)', 'tumore renale nas', 'tumore maligno renale', 'tumor maligno de riñón (trastorno)', 'nierentumor', 'tumor maligno del riñón (trastorno)', 'nierneoplasmata', 'malignant tumor of the kidney', '腎新生物ｎｏｓ', 'tumor of the kidney', '신장 종양 형성', 'neubildung der niere', 'neoplasie del rene', 'neoplasia del riñón (trastorno)', 'neoplasia renal ne', 'ca - cancer of kidney', 'неоплазма почки', 'malignant tumour of kidney', 'njurtumörer', 'neubildung der nieren nnb', 'munuaiskasvaimet', 'cancer, renal', 'malignant neoplasm of kidney, nos', '腎癌', '신장암', 'kidney cancer', 'tumor of kidney', 'tumeur rénale maligne', 'neoplasie der niere', 'cancer, kidney', 'ｼﾞﾝﾉｱｸｾｲｼﾝｾｲﾌﾞﾂ', 'malignant neoplasm of kidney nos', 'boesartige neubildung der niere', 'ca - renal cancer', '각종 신장 신생물', 'renal cancer', '腎臓がん', 'sartan hakilya', 'neoplasia del riñón', 'renal tumour', 'nierneoplasma', 'pochek novoobrazovaniia', 'cancer du rein', 'неоплазия почки', 'malignant tumour of kidney (disorder)', 'malignant renal tumor', 'tumori renali maligni', 'novotvar ledviny', 'renaler krebs', 'tumore gaiztoa, giltzurruna', '腎癌(腎臓腫瘍)', '신장 종양', '신장 종양 nos', 'ledviny - nádory', 'cancers, kidney', 'nierneoplasie', 'cancro del rene', 'câncer renal', 'cancer rénal', 'neoplasm, renal', 'kidney cancer (diagnosis)', 'nierneoplasmata maligne', 'krebs der niere', 'новообразование почки', 'nádor ledviny', 'neoplasie maligne del rene', 'kidney neoplasms', 'neoplasia renal', 'boesartige renale neubildung', 'renal malignant neoplasm', 'câncer do rim', 'néoplasie rénale', 'nyrecancer', 'neopl kidney', 'renální neoplazie', 'veserák', 'renalis neoplasia', 'tumeur rénale sai', 'neoplasmer i nyre', 'nyresvulster', 'renal neoplasia', 'cancer rein', 'nowotwory nerek', 'tumour of kidney', 'tumeurs rénales', 'nyrekreft', '신장 신생물', 'rakovina ledvin', 'maligní novotvar ledviny', 'neoplasias malignas del rinon', 'tumor renal', 'cáncer renal', '腎腫瘍', 'renální novotvary maligní', 'malignant tumor of kidney', 'cancer of the kidney', 'tumeur du rein', 'neoplasm, kidney', 'neoplasia renal maligna', 'neubildungen der niere', 'kidney neoplasm', 'tumore del rene', '腎盂腫瘍', 'tumor do rim', 'tumori renali', 'malignant renal neoplasm', 'neoplasma nier', 'neoplasms, renal', 'neoplasm of kidney (diagnosis)', 'tumeurs rénales malignes', 'neoplasms, kidney', 'malignant neoplasm of kidney', 'niergezwellen', 'niertumor', 'renális neoplasmák, rosszindulatú', 'renal tumours', 'cáncer del riñón', 'новообразования почек', 'tumor no rim', 'munuaisen pahanlaatuinen kasvain', '腎新生物', 'njurcancer', '腎臓腫瘍', 'renal cancers', 'kreft i nyre', 'tumoren, nieren-', 'neoplasias renales', 'maligne neoplasma van de nier', '腎臓癌', 'ｼﾞﾝｼﾝｾｲﾌﾞﾂ', 'nierenkrebs', 'renální nádor', 'nierentumoren', 'renal neoplasms', 'nierkanker', 'vese rákja', 'malignant tumor of kidney (disorder)', 'cancers, renal', 'tumor maligno de riñón', 'novotvary ledvin', 'renal malignant tumor', 'злокачественное новообразование почки', '腎臓新生物', 'câncer dos rins', 'kidney tumours', 'neoplasias renales malignas', 'новообразование почки бду', 'nierenneoplasie', 'neoplasm malig;kidney', 'tumeurs du rein', 'malignant renal tumors', '악성 신장 신생물', 'neoplasia maligna do rim', 'renal malignant tumour', 'malignant neoplasm of kidney (diagnosis)', 'ondartet svulst nyre', 'neoplasm of the kidney', 'vese malignus tumora', 'рак почки', 'maligne neoplasma nier', 'ｼﾞﾝｿﾞｳｼﾝｾｲﾌﾞﾂ', 'cancers rénaux', 'cancer of kidney', 'ｼﾞﾝｼｭﾖｳ', 'ｱｸｾｲｼﾞﾝｼﾝｾｲﾌﾞﾂ', 'malign njurtumor', 'ｼﾞﾝｶﾞﾝ', 'tumor maligno del riñón', 'malignant neoplasm of the kidney', 'novotvar ledviny nos', 'renal tumor', 'ｼﾞﾝｼﾝｾｲﾌﾞﾂnos', 'neoplasie renali', 'vese rosszindulatú neoplasiája', 'renal neoplasm nos', 'опухоль почки', 'neoplasia renale', 'renális neoplasmák', 'bubrežni tumori', 'kidney tumor', 'neoplasias renais', 'neoplasias renais malignas', 'cancro renale', 'nierneoplasma nao', 'почек новообразования', 'renal neoplasm', 'niergezwel', 'vese  ...
# ranks: [('Oncology', 0.783486), ('Infections and Infectious Diseases', 0.572138), ('Genetic Disease', 0.54899085), ('Pulmonary/Respiratory Diseases', 0.49592406), ('Dental and Oral Health', 0.49186158)]
#
# study: NCT02342613
# terms: {'cancer nos', '腫瘍', 'neoplasm malignant', 'dobroćudna novotvorina', 'ondartede tumorer', 'malignant tumour', 'cancro (nas)', 'malig neop of unspec site nos', 'tumori benigni, maligni e non specificati (incl cisti e polipi)', 'tumore benigno di sede non specificata', 'malignant tumors', '悪性新生物', 'neoplasia neom', '腹水ガン', 'gutartige neubildung an nicht naeher bezeichneter lokalisation', 'malignant neoplasm of unspecified site', 'malignancy, unspecified site', 'tumor; maligne, ongeclassificeerd', 'malignancy nos', 'tumore maligno senza indicazione della sede', 'tumores malignos', "mal neo w'out specfctn/site", 'ng - neoplastic growth', 'new growth', 'neoplasm (morphologic abnormality)', 'новообразования', '実験動物腫瘍', 'neoplasia maligna de localización no especificada, sai (trastorno)', 'nem meghatározott helyű jóindulatú neoplasia', 'rakovina', 'malignant tumoral disease', 'maligne neoplasmer', '実験発ガン', '종양', 'tumor nos', 'ca - unspecified site nos', 'ca - unspecified site nos (disorder)', 'benigní nádory', 'malignancies', 'opukholi', '악성 신생물', 'elakartad cancer', 'cancer', 'nádory', 'neoplastic syndrome', 'novotvar (nos)', 'neoplazme', 'malignant tumor', 'опухоли', 'ｱｸｾｲｼﾝｾｲﾌﾞﾂﾌﾞｲﾌﾒｲ', 'neoplasia maligna sem especificação de local', 'tumor', 'cancer, nos', 'ﾘｮｳｾｲｼﾝｾｲﾌﾞﾂnos', 'cancer, unspecified site', 'benign neoplasm', 'neoplasien des bewegungsapparates', 'malignant, benign, and unspecified neoplasms, cysts, polyps (diagnosis)', 'novotvar nos', 'tumore maligno', 'boesartige neubildung ohne angabe der lokalisation', 'cancro ne', 'noncancerous tumors', 'tumour, benign', 'gutartige, boesartige und nicht spezifizierte neubildungen (einschl. zysten und polypen)', 'benign neoplasm (diagnosis)', 'benign unclassifiable tumor', 'maligne neoplasma zonder specificatie van de plaats', 'new growth nos', 'malignus tumor', 'neoplasms, nos', 'unclassified tumour, benign', 'benigní novotvar nos', '実験的腫瘍', 'gutartige neubildung einer nicht spezifizierten stelle', 'neoplasia benigna soe', 'neoplasm benign;site unspecifi', 'malignant neoplasm', '신생물', 'benign neoplasm, unspecified site', '암', 'daganat', 'nádorové onemocnění', 'tumeur', 'cáncer (neom)', '良性新生物', 'tumor benigno', 'unclassified tumour, malignant', 'neoplasm - benign, malignant, unspecified (including cysts, polyps)', 'tumorerkrankungen', 'neoplasme', 'maligní nádor (nos)', 'neoplasia maligna (trastorno)', 'tumours', '腹水がん', 'neoplasms, malignant', 'morfología de tumor benigno', 'tumor, malignant, nos', 'neoplasm nos', 'новообразование бду', 'ｶﾞﾝ', 'rosszindulatú tumor', 'benigní novotvar blíže neurčeného místa', 'neoplasm, nos', 'tumore maligno nas', 'ondartede svulster', 'neoplasma benigne', 'neoplasms benign, malignant and unspecified (including cysts and polyps)', 'dmba誘発腫瘍', 'nonmalignant neoplasm', 'tumor, sai', 'tumeur bénigne sai', 'benign tumour', 'ﾘｮｳｾｲｼﾝｾｲﾌﾞﾂ', 'neoplasia benigna, sai', 'benign neoplasm of unspecified site', '腹水癌', 'neoplasmos', 'cancer (nos)', 'tumeurs malignes', 'доброкачественное новообразование', '癌（ｎｏｓ）', 'tumore benigno', 'tumeurs bénignes, malignes et non précisées (incl kystes et polypes)', '新生物', 'godartede neoplasmer', 'tumore nas', 'novotvorine', 'malignant neoplasm without specification of site', 'neoplasia maligna de localización no especificada (trastorno)', 'tumour', 'neoformazione', 'neoplasms nos', '[x]neoplasia maligna sin especificación de la localización (trastorno)', 'neoplasias benignas, malignas y no especificadas (incl quistes y pólipos)', 'neoplasmer', 'novotvary benigní, maligní a blíže neurčené (zahrnující cysty a polypy)', 'neoplasms benign, malignant and unspecified (incl cysts and polyps)', 'neoplasma (nao)', 'novotvar', 'zloćudna novotvorina', 'maligní nádor', 'maligne neoplasma zonder gespecificeerde lokalisatie', 'neoplasia (soe)', '良性、悪性および詳細不明の新生物（嚢胞およびポリープを含む）', 'злокачественное новообразование без указания локализации', 'zlokachestvennoe novoobrazovanie', '^cancer', 'malignant neoplastic disease', 'rák', 'neoplasi ...
# ranks: [('Oncology', 0.7387136), ('Genetic Disease', 0.3097341), ('Otolaryngology', 0.30179918), ('Rheumatology', 0.30048826), ('Gastroenterology', 0.30014747)]
#
# study: NCT02340117
# terms: {'췌장암', 'câncer pancreático', 'рак в поджелудочной железе', 'malignant neoplasm of pancreas, part unspecified', 'kreft i bukspyttkjertelen', 'pankreas - nádory', 'ca pancreas nos', 'cáncer de páncreas', 'tumorer i pancreas', 'malignus pancreas tumor', 'tumeur maligne du pancréas', 'maligní novotvar pankreatu', 'bukspottkörteltumörer', 'tumor maligno del páncreas (trastorno)', 'pankreassvulster', 'neoplasia maligna do pâncreas, parte não especificada', 'ca - cancer of pancreas', 'pancreassvulster', 'рак поджелудочной железы', 'pancreasneoplasma maligne', 'pancreasneoplasma nao', 'tumores do pâncreas', 'neoplasia pancreática', '췌장의 악성 신생물', 'ondartet svulst i bugspytkirtel', 'boesartige neubildung: pankreas, nicht naeher bezeichnet', 'kreft i pankreas', 'tumor of pancreas', 'neoplasm malig;pancreas', '膵腫瘍', 'cancro pancreatico', 'cancro pancreático', 'tumori del pancreas', 'новообразования поджелудочной железы', 'neoplasia de páncreas', 'haiman kasvaimet', 'hasnyálmirigyrák', 'cancer du pancreas', 'tumore del pancreas', 'neoplasia maligna de páncreas (trastorno)', 'tumour of pancreas', 'neoplasia maligna de páncreas, parte no especificada', 'pancreas neoplasia k.m.n.', 'novotvar pankreatu maligní', 'pankreatický novotvar nos', 'neoformazione pancreatica', 'karcinom pankreatu', 'malignant neoplasm of pancreas, unspecified', '膵がん', 'pancreasrák', 'pancreaskreft', 'pancreas--cancer', '膵臓腫瘍', '膵の悪性新生物', 'neoplasm, pancreatic', 'neoplasmer i bukspyttkjertelen', 'cancer, pancreatic', 'malignant tumor of pancreas', 'cancer pancréatique', 'malignant neoplasm of the pancreas', 'neoplasmer i pankreas', '膵悪性腫瘍', 'karcinom slinivky břišní', 'gezwellen, pancreas-', 'maligní nádor pankreatu', 'tumeur du pancréas', 'neoplasia maligna de páncreas', 'hasnyálmirigy neoplasia k.m.n.', 'cáncer pancreático', 'tumore del pancreas nas', 'cancer of the pancreas', 'cancers, pancreas', 'neoplasia maligna do pâncreas', 'nádor slinivky břišní', 'malig neo pancreas nos', 'neoplasia de páncreas (trastorno)', 'neoplasia pancreática ne', 'tumor of the pancreas', 'areko tumore gaiztoa', 'nádor pankreatu', 'neoplasm pancreas', 'neoplasie maligne pancreas', 'câncer do pâncreas', '膵新生物', 'cancer of pancreas', 'rakovina pankreatu', 'neoplasmer i pancreas', '부위 상세 불명의 췌장의 악성 신생물', 'pancreatic tumor or cancer', 'neubildung des pankreas', 'tumor van de pancreas', 'malignant neoplasm of pancreas (diagnosis)', 'pancreas ca', 'злокачественное новообразование поджелудочной железы', 'svulster i bukspyttkjertelen', 'pancreaskanker', 'neoplasia do pâncreas ne', 'злокачественное новообразование поджелудочной железы, неуточненная часть', 'kreft i pancreas', 'tumour pancreas', 'tumore maligno del pancreas nas', 'pancreatic neopl', 'pankreascancer', 'pancreatic cancer', 'ｽｲｼﾝｾｲﾌﾞﾂ', 'boesartige neubildung des pankreas, teil nicht spezifiziert', 'ca - pancreatic cancer', 'tumore maligno del pancreas, parte non specificata', 'cáncer de páncreas, sai', 'ca pancreas nos (disorder)', 'neoplasma pankreas malignes', 'neoplasia del pancreas neom', 'ｽｲﾉｱｸｾｲｼﾝｾｲﾌﾞﾂﾌﾞｲﾌﾒｲ', 'neoplasms, pancreatic', 'pancreasneoplasmata', 'tumeur du pancréas sai', '膵頭部領域癌', '膵尾部癌', 'tumor pancreas', '각종 췌장 신생물', 'neoplasia maligna do pancreas', 'tumorer i pankreas', 'neoplasias malignas pancreas', 'bukspottkörtelcancer', 'neoplasm of the pancreas', 'neoplasms pancreas', 'neoplasm of pancreas (diagnosis)', 'neoplasia maligna de páncreas, sai', 'новообразование поджелудочной железы', 'neoplasia pancreática soe', 'bukspyttkjertelkreft', 'pankreastumörer', 'neoplasm of pancreas', 'maligne neoplasma pancreas', 'pancreas, unspecified', 'neoplasia of the pancreas', 'svulster i pankreas', 'maligne neoplasma van de pancreas', 'cancer, pancreas', '膵鉤部癌', 'neoplasie del pancreas', 'pancreas neoplasm', 'neoplasma des pankreas nnb', 'rakovina slinivky břišní', 'neoplasia pancreática neom', 'новообразование поджелудочной железы, злокачественное', 'pancreas cancer malignant', 'ｽｲｶﾞﾝ', 'malignant neoplasm of pancrea ...
# ranks: [('Oncology', 0.6522629), ('Endocrinology', 0.32703882), ('Immunology', 0.31423786), ('Infections and Infectious Diseases', 0.31027716), ('Genetic Disease', 0.28725016)]
#
# ======= Neurology ==========
# study: NCT02347995
# terms: {'cerebrovaskularni incident', 'accidente cerebrovascolare nas', 'stroke unspecified', 'cerebrovascular accident', 'stroke, cerebrovascular', 'accident; cerebrovasculair', 'apopleksiia mozga', 'agyergorcs/agyverzes', 'slag', 'zerebrovaskuläre apoplexie', 'cva nos', 'acidente vascular cerebral ne', 'incidente cerebrovascolare', 'colpo/accidente cerebrovascolare', 'ictus', 'udar mózgowy', 'cva (incidente cerebrovascolare)', 'инсульт цереброваскулярный', 'stroke', 'accidentes cerebrovasculares', 'hjärnattack', 'cerebrovascular apoplexy', 'apoplexia cerebrovascular', 'tserebrovaskuliarnaia apopleksiia', 'stroke and cerebrovascular accident unspecified', 'цереброваскулярная апоплексия', 'atakea/ezbehar baskular burmuinetakoa', '脳血管発作ｎｏｓ', 'apopleksi', 'acidentes cerebrais vasculares', 'iktus', 'stroke cerebral', 'accident, cerebrovasculair', 'cévní mozková příhoda', 'cva - cerebrovascular accident (& unspecified [& stroke])', 'cerebrovasculaire apoplexie', 'stroke nos', 'brain attack', 'ﾉｳｹｯｶﾝﾎｯｻ', 'stroke/cerebrovasc accident', '뇌혈관 사고 nos', 'апоплексия мозга', 'ictus cerebrale', 'stroke and cerebrovascular accident unspecified (disorder)', '脳クリーゼ', 'accidente cerebrovascular, no especificado', 'brain vascular accidents', 'cmp', '発作症候群', 'stroke/cva - undefined', 'accident, cérébrovasculaire', 'apoplexia', 'moždani udar', 'stroke/cva', 'accidente cerebrovascular, sai', 'moždana kap', 'ostry udar mózgu', 'cerebrovasculair accident (cva)', 'cva - cerebrovascular accident', 'apoplexie; cerebraal', 'cerebraal; accident', 'acidentes cerebrovasculares', 'stroke, cerebral', 'cerebraovascularis insultus', '脳卒中', 'cva - cerebrovascular accident (& unspecified [& stroke]) (disorder)', '後頭蓋卒中', 'accident vasculaire cerebral', 'vascular accident, brain', '卒中発作', 'mozková mrtvice', 'accident; cerebraal', '脳発症', 'cerebrovascularis esemény', 'ﾉｳｹｯｶﾝﾎｯｻnos', 'acv, sai', 'schlaganfall', 'ストローク', 'hjerneslag', 'cerebrovasculair accident', 'apopleksi/cerebrovaskulaer katastr', 'accident cérébrovasculaire', 'accidente cerebrovascular (trastorno)', 'accident vasculaire cérébral', 'онмк', 'aivohalvaus', 'zerebrovaskulärer insult', 'cerebral apoplexy, nos', 'acidente cerebral vascular', 'cerebrovascular accident (disorder)', 'acidente cerebrovascular', 'vascular cerebral accident', 'apoplexy, nos', 'hjerneslag/cerebrovask katastrofe', 'cva', 'beroerte', 'avc', '卒中', 'vascular accidents, brain', 'accidente vascular cerebral', 'apoplejía', 'cerebraal; apoplexie', 'cva (cerebral vascular accident)', 'cva (cerebrovascular accident)', 'strokes, cerebral', 'acidente vascular cerebral', 'mozková příhoda', 'apoplessia cerebrovascolare', 'schlaganfall, nicht als blutung oder infarkt bezeichnet', 'stroke/cerebrovascular accident', 'accident cerebrovascular', '脳出血発作症候群', 'apoplexia cerebral', 'strokes, cerebrovascular', 'cerebrovascular accident (disorder) [ambiguous]', '뇌졸중', 'accidente cerebrovascular', 'accidente cerebrovascolare', 'accident cerebrovasculair', 'erua moxi', 'accidente vascular encefálico', 'cerebrovasculair; accident', 'vascular brain accident', 'stroke, nos', 'avc (accident vasculaire cérébral)', 'vasculair accident van de hersenen', 'ataque', 'cva - cerebrovascular accident unspecified', 'apoplexie', 'apoplexie; beroerte', 'schlaganfall nnb', 'cévní mozková příhoda nos', 'acidente vascular cerebral soe', 'ataque cerebral', 'cerebral stroke', 'vaskulärer insult des gehirns', 'slaganfall', 'accidente vascular del cerebro', 'cerebral apoplexy', 'accidente cerebrovascular, no especificado (trastorno)', 'stroke, not specified as hemorrhage or infarction', 'stroke; apoplectic', 'ﾉｳｿｯﾁｭｳ', "attaque d'apoplexie", 'stroke, not specified as haemorrhage or infarction', 'apoplexy, cerebral', 'stroke syndrome', 'apoplektischer insult', 'acidente/doenca cerebrovascular', 'cerebrovasculair accident nao', 'cerebrovascular stroke', 'cerebrovaskulär apoplexi', 'cerebral strokes', 'accident ischémique cérébral', 'ictus cerebral', 'cerebrale beroerte', "in ...
# ranks: [('Neurology', 0.4360425), ('Cardiology/Vascular Diseases', 0.42245397), ('Trauma', 0.3741505), ('Nephrology', 0.3043946), ('Sleep', 0.3010249)]
#
# study: NCT02369770
# terms: {'cerebrovaskularni incident', 'accidente cerebrovascolare nas', 'stroke unspecified', 'cerebrovascular accident', 'stroke, cerebrovascular', 'accident; cerebrovasculair', 'apopleksiia mozga', 'agyergorcs/agyverzes', 'slag', 'zerebrovaskuläre apoplexie', 'cva nos', 'acidente vascular cerebral ne', 'incidente cerebrovascolare', 'colpo/accidente cerebrovascolare', 'ictus', 'udar mózgowy', 'cva (incidente cerebrovascolare)', 'инсульт цереброваскулярный', 'stroke', 'accidentes cerebrovasculares', 'hjärnattack', 'cerebrovascular apoplexy', 'apoplexia cerebrovascular', 'tserebrovaskuliarnaia apopleksiia', 'stroke and cerebrovascular accident unspecified', 'цереброваскулярная апоплексия', 'atakea/ezbehar baskular burmuinetakoa', '脳血管発作ｎｏｓ', 'apopleksi', 'acidentes cerebrais vasculares', 'iktus', 'stroke cerebral', 'accident, cerebrovasculair', 'cévní mozková příhoda', 'cva - cerebrovascular accident (& unspecified [& stroke])', 'cerebrovasculaire apoplexie', 'stroke nos', 'brain attack', 'ﾉｳｹｯｶﾝﾎｯｻ', 'stroke/cerebrovasc accident', '뇌혈관 사고 nos', 'апоплексия мозга', 'ictus cerebrale', 'stroke and cerebrovascular accident unspecified (disorder)', '脳クリーゼ', 'accidente cerebrovascular, no especificado', 'brain vascular accidents', 'cmp', '発作症候群', 'stroke/cva - undefined', 'accident, cérébrovasculaire', 'apoplexia', 'moždani udar', 'stroke/cva', 'accidente cerebrovascular, sai', 'moždana kap', 'ostry udar mózgu', 'cerebrovasculair accident (cva)', 'cva - cerebrovascular accident', 'apoplexie; cerebraal', 'cerebraal; accident', 'acidentes cerebrovasculares', 'stroke, cerebral', 'cerebraovascularis insultus', '脳卒中', 'cva - cerebrovascular accident (& unspecified [& stroke]) (disorder)', '後頭蓋卒中', 'accident vasculaire cerebral', 'vascular accident, brain', '卒中発作', 'mozková mrtvice', 'accident; cerebraal', '脳発症', 'cerebrovascularis esemény', 'ﾉｳｹｯｶﾝﾎｯｻnos', 'acv, sai', 'schlaganfall', 'ストローク', 'hjerneslag', 'cerebrovasculair accident', 'apopleksi/cerebrovaskulaer katastr', 'accident cérébrovasculaire', 'accidente cerebrovascular (trastorno)', 'accident vasculaire cérébral', 'онмк', 'aivohalvaus', 'zerebrovaskulärer insult', 'cerebral apoplexy, nos', 'acidente cerebral vascular', 'cerebrovascular accident (disorder)', 'acidente cerebrovascular', 'vascular cerebral accident', 'apoplexy, nos', 'hjerneslag/cerebrovask katastrofe', 'cva', 'beroerte', 'avc', '卒中', 'vascular accidents, brain', 'accidente vascular cerebral', 'apoplejía', 'cerebraal; apoplexie', 'cva (cerebral vascular accident)', 'cva (cerebrovascular accident)', 'strokes, cerebral', 'acidente vascular cerebral', 'mozková příhoda', 'apoplessia cerebrovascolare', 'schlaganfall, nicht als blutung oder infarkt bezeichnet', 'stroke/cerebrovascular accident', 'accident cerebrovascular', '脳出血発作症候群', 'apoplexia cerebral', 'strokes, cerebrovascular', 'cerebrovascular accident (disorder) [ambiguous]', '뇌졸중', 'accidente cerebrovascular', 'accidente cerebrovascolare', 'accident cerebrovasculair', 'erua moxi', 'accidente vascular encefálico', 'cerebrovasculair; accident', 'vascular brain accident', 'stroke, nos', 'avc (accident vasculaire cérébral)', 'vasculair accident van de hersenen', 'ataque', 'cva - cerebrovascular accident unspecified', 'apoplexie', 'apoplexie; beroerte', 'schlaganfall nnb', 'cévní mozková příhoda nos', 'acidente vascular cerebral soe', 'ataque cerebral', 'cerebral stroke', 'vaskulärer insult des gehirns', 'slaganfall', 'accidente vascular del cerebro', 'cerebral apoplexy', 'accidente cerebrovascular, no especificado (trastorno)', 'stroke, not specified as hemorrhage or infarction', 'stroke; apoplectic', 'ﾉｳｿｯﾁｭｳ', "attaque d'apoplexie", 'stroke, not specified as haemorrhage or infarction', 'apoplexy, cerebral', 'stroke syndrome', 'apoplektischer insult', 'acidente/doenca cerebrovascular', 'cerebrovasculair accident nao', 'cerebrovascular stroke', 'cerebrovaskulär apoplexi', 'cerebral strokes', 'accident ischémique cérébral', 'ictus cerebral', 'cerebrale beroerte', "in ...
# ranks: [('Neurology', 0.4360425), ('Cardiology/Vascular Diseases', 0.42245397), ('Trauma', 0.3741505), ('Nephrology', 0.3043946), ('Sleep', 0.3010249)]
#
# study: NCT02365090
# terms: {'ambliopía anisometrópica (trastorno)', 'unspecified amblyopia', 'oeil paresseux', 'amblyopie door suppressie', 'anisometropie-amblyopie', 'amblyopie par privation de stimulus visuel', 'ojo perezoso (hallazgo)', 'anisometropic amblyopia', 'amblyopia, nem meghatározott', 'amblyopia suppression', 'amblyopia, nos', 'ｼﾞｬｸｼｶﾞﾝ', 'amblyopia, unspecified', 'ambliopia, non specificata', 'anisometropi-amblyopi', 'amblyopia', 'ambliopía no especificada (trastorno)', 'amblyopia, stimulus deprivation-induced', 'ambliopia por supressão', 'lazy eye', 'strabismusos amblyopia', 'amblyopia; anisometropic', 'olho vago', 'unspecified amblyopia (disorder)', 'ambliopia anisometropica', 'eye lazy', 'suppression amblyopias', 'occhio pigro', 'eye, lazy', 'ambliopia ne', 'tompalátás', 'ambliopia soe', 'stimulus deprivation-induced amblyopia', 'ｼﾞｬｸｼｼｮｳｻｲﾌﾒｲ', 'strabismus okozta amblyopia', 'heikkonäköisyys', 'ambliopía por estrabismo (trastorno)', 'ambliopija', 'amblyopie strabique', 'ｼﾞｬｸｼ', 'sehleistung, herabgesetzte', '弱視、詳細不明', 'occhio ambliopico', 'ambliopia estrábica', 'ambliopiia', 'anisometropisk amblyopi', 'ambliopia por estrabismo', 'amblyopie, non précisée', 'amblyopias, anisometropic', 'amblyopie de privation', 'schielamblyopie', 'ambliopia da soppressione', 'niedowidzenie', 'anisometropiamblyopi', 'amblyopic', 'амблиопия, неуточненная', 'amblyopie par déprivation', 'lenivé oko', 'stimulus deprivation-induced amblyopias', 'deprivasjonsamblyopi', 'амблиопичный глаз', 'amblyopie sai', '약시 nos', 'tupozrakost, blíže neurčená', 'amblyopie nnb', 'ambliopia anisometrópica', 'амблиопия с супрессией', '사시 약시', 'amblyopi grunnet deprivasjon', 'anizometropická amblyopie', 'anisometropic amblyopia (disorder)', 'líné oko', 'ambliopía por estrabismo', 'amblyopie anisométropique', 'suppressieamblyopie', 'ambliopia', 'amblyopia, stimulus deprivation induced', 'amblyopiesuppression', 'ambliopía estrábica', 'amblyopi', 'strabismic amblyopia', 'ambliopia strabica', 'amblyopia ex anopsia', 'anisometropic; amblyopia', 'амблиопия с косоглазием', 'strabická amblyopie', 'amblyopi grunnet suppresjon', 'amblyopias, suppression', 'amblyopia suppressio', 'amblyopie liée au strabisme', 'amblyopie; anisometropisch', 'амблиопия, бду', 'amblyopia, strabismic', 'syndrom líného oka', 'ambliopía (trastorno)', "amblyopie par défaut d'usage", '抑制弱視', 'amblyopie, nicht spezifiziert', 'ambliopía anisometrópica', 'ambliopia da deprivazione visiva', 'supresní tupozrakost', 'amblyopia strabismic', 'suppressionsamblyopie', '억제 약시', '상세 불명의 약시', 'amblyopia (disorder)', 'amblyopie nos', 'amblyopia stimulus deprivation ind', 'strabisme-amblyopie', 'amblyopie par suppression', 'suppresjonsforårsaket amblyopi', 'amblyopie', 'anisometropisch; amblyopie', 'eyes, lazy', 'lazy eyes', 'amblyopi, suppresjon', 'amblyopia, suppression', 'amblyopie nao', 'amblyopias', 'amblyopi ved anisometropi', 'supresní amblyopie', 'strabismic amblyopia (diagnosis)', 'ｼｬｼｼﾞｬｸｼ', 'lui oog', '약시', 'ambliopía no especificada', 'ambliopia, não especificada', 'tupozrakost', 'olho preguiçoso', 'suppressions-amblyopie', 'stimulus-deprivations-amblyopie', 'schwachsichtigkeit', 'strabismic amblyopia (disorder)', 'amblyopia, anisometropic', '弱視', 'amblyopia anisometropic', 'ambliopía', 'ojo perezoso', 'suppression amblyopia', 'lazy eye (finding)', 'amblyopia k.m.n.', 'amblyopie jako důsledek potlačení zrakového vjemu', 'амблиопия', 'ojo vago', 'амблиопия при косоглазии', 'ﾖｸｾｲｼﾞｬｸｼ', '弱視眼', 'amblyopie, niet-gespecificeerd', 'amblyopia (diagnosis)', 'ambliopia nas', 'stimulus deprivation ind amblyopia', '弱視ｎｏｓ', 'amblyopias, stimulus deprivation-induced', '斜視弱視', 'amblyopia nos', 'anisometropische amblyopie', 'deprivation-induced amblyopia, stimulus', 'deprivation-induced amblyopias, stimulus', 'амблиопическая супрессия', 'anisometropic amblyopia (diagnosis)', 'ambliopía neom', 'ｼﾞｬｸｼnos', 'ambliopía por supresión', 'amblyopie vyvolaná potlačením zrakového vjemu', 'wandering eyes', 'stimulus deprivation induced ...
# ranks: [('Neurology', 0.7698219), ('Pediatrics/Neonatology', 0.7524388), ('Ophthalmology', 0.7345383), ('Trauma', 0.7304384), ('Musculoskeletal', 0.7160543)]
#
# study: NCT02359812
# terms: {'cerebrovaskularni incident', 'accidente cerebrovascolare nas', 'stroke unspecified', 'cerebrovascular accident', 'stroke, cerebrovascular', 'accident; cerebrovasculair', 'apopleksiia mozga', 'agyergorcs/agyverzes', 'slag', 'zerebrovaskuläre apoplexie', 'cva nos', 'acidente vascular cerebral ne', 'incidente cerebrovascolare', 'colpo/accidente cerebrovascolare', 'ictus', 'udar mózgowy', 'cva (incidente cerebrovascolare)', 'инсульт цереброваскулярный', 'stroke', 'accidentes cerebrovasculares', 'hjärnattack', 'cerebrovascular apoplexy', 'apoplexia cerebrovascular', 'tserebrovaskuliarnaia apopleksiia', 'stroke and cerebrovascular accident unspecified', 'цереброваскулярная апоплексия', 'atakea/ezbehar baskular burmuinetakoa', '脳血管発作ｎｏｓ', 'apopleksi', 'acidentes cerebrais vasculares', 'iktus', 'stroke cerebral', 'accident, cerebrovasculair', 'cévní mozková příhoda', 'cva - cerebrovascular accident (& unspecified [& stroke])', 'cerebrovasculaire apoplexie', 'stroke nos', 'brain attack', 'ﾉｳｹｯｶﾝﾎｯｻ', 'stroke/cerebrovasc accident', '뇌혈관 사고 nos', 'апоплексия мозга', 'ictus cerebrale', 'stroke and cerebrovascular accident unspecified (disorder)', '脳クリーゼ', 'accidente cerebrovascular, no especificado', 'brain vascular accidents', 'cmp', '発作症候群', 'stroke/cva - undefined', 'accident, cérébrovasculaire', 'apoplexia', 'moždani udar', 'stroke/cva', 'accidente cerebrovascular, sai', 'moždana kap', 'ostry udar mózgu', 'cerebrovasculair accident (cva)', 'cva - cerebrovascular accident', 'apoplexie; cerebraal', 'cerebraal; accident', 'acidentes cerebrovasculares', 'stroke, cerebral', 'cerebraovascularis insultus', '脳卒中', 'cva - cerebrovascular accident (& unspecified [& stroke]) (disorder)', '後頭蓋卒中', 'accident vasculaire cerebral', 'vascular accident, brain', '卒中発作', 'mozková mrtvice', 'accident; cerebraal', '脳発症', 'cerebrovascularis esemény', 'ﾉｳｹｯｶﾝﾎｯｻnos', 'acv, sai', 'schlaganfall', 'ストローク', 'hjerneslag', 'cerebrovasculair accident', 'apopleksi/cerebrovaskulaer katastr', 'accident cérébrovasculaire', 'accidente cerebrovascular (trastorno)', 'accident vasculaire cérébral', 'онмк', 'aivohalvaus', 'zerebrovaskulärer insult', 'cerebral apoplexy, nos', 'acidente cerebral vascular', 'cerebrovascular accident (disorder)', 'acidente cerebrovascular', 'vascular cerebral accident', 'apoplexy, nos', 'hjerneslag/cerebrovask katastrofe', 'cva', 'beroerte', 'avc', '卒中', 'vascular accidents, brain', 'accidente vascular cerebral', 'apoplejía', 'cerebraal; apoplexie', 'cva (cerebral vascular accident)', 'cva (cerebrovascular accident)', 'strokes, cerebral', 'acidente vascular cerebral', 'mozková příhoda', 'apoplessia cerebrovascolare', 'schlaganfall, nicht als blutung oder infarkt bezeichnet', 'stroke/cerebrovascular accident', 'accident cerebrovascular', '脳出血発作症候群', 'apoplexia cerebral', 'strokes, cerebrovascular', 'cerebrovascular accident (disorder) [ambiguous]', '뇌졸중', 'accidente cerebrovascular', 'accidente cerebrovascolare', 'accident cerebrovasculair', 'erua moxi', 'accidente vascular encefálico', 'cerebrovasculair; accident', 'vascular brain accident', 'stroke, nos', 'avc (accident vasculaire cérébral)', 'vasculair accident van de hersenen', 'ataque', 'cva - cerebrovascular accident unspecified', 'apoplexie', 'apoplexie; beroerte', 'schlaganfall nnb', 'cévní mozková příhoda nos', 'acidente vascular cerebral soe', 'ataque cerebral', 'cerebral stroke', 'vaskulärer insult des gehirns', 'slaganfall', 'accidente vascular del cerebro', 'cerebral apoplexy', 'accidente cerebrovascular, no especificado (trastorno)', 'stroke, not specified as hemorrhage or infarction', 'stroke; apoplectic', 'ﾉｳｿｯﾁｭｳ', "attaque d'apoplexie", 'stroke, not specified as haemorrhage or infarction', 'apoplexy, cerebral', 'stroke syndrome', 'apoplektischer insult', 'acidente/doenca cerebrovascular', 'cerebrovasculair accident nao', 'cerebrovascular stroke', 'cerebrovaskulär apoplexi', 'cerebral strokes', 'accident ischémique cérébral', 'ictus cerebral', 'cerebrale beroerte', "in ...
# ranks: [('Neurology', 0.4360425), ('Cardiology/Vascular Diseases', 0.42245397), ('Trauma', 0.3741505), ('Nephrology', 0.3043946), ('Sleep', 0.3010249)]
#
# study: NCT02359253
# terms: {'cerebrovaskularni incident', 'accidente cerebrovascolare nas', 'stroke unspecified', 'cerebrovascular accident', 'stroke, cerebrovascular', 'accident; cerebrovasculair', 'apopleksiia mozga', 'agyergorcs/agyverzes', 'slag', 'zerebrovaskuläre apoplexie', 'cva nos', 'acidente vascular cerebral ne', 'incidente cerebrovascolare', 'colpo/accidente cerebrovascolare', 'ictus', 'udar mózgowy', 'cva (incidente cerebrovascolare)', 'инсульт цереброваскулярный', 'stroke', 'accidentes cerebrovasculares', 'hjärnattack', 'cerebrovascular apoplexy', 'apoplexia cerebrovascular', 'tserebrovaskuliarnaia apopleksiia', 'stroke and cerebrovascular accident unspecified', 'цереброваскулярная апоплексия', 'atakea/ezbehar baskular burmuinetakoa', '脳血管発作ｎｏｓ', 'apopleksi', 'acidentes cerebrais vasculares', 'iktus', 'stroke cerebral', 'accident, cerebrovasculair', 'cévní mozková příhoda', 'cva - cerebrovascular accident (& unspecified [& stroke])', 'cerebrovasculaire apoplexie', 'stroke nos', 'brain attack', 'ﾉｳｹｯｶﾝﾎｯｻ', 'stroke/cerebrovasc accident', '뇌혈관 사고 nos', 'апоплексия мозга', 'ictus cerebrale', 'stroke and cerebrovascular accident unspecified (disorder)', '脳クリーゼ', 'accidente cerebrovascular, no especificado', 'brain vascular accidents', 'cmp', '発作症候群', 'stroke/cva - undefined', 'accident, cérébrovasculaire', 'apoplexia', 'moždani udar', 'stroke/cva', 'accidente cerebrovascular, sai', 'moždana kap', 'ostry udar mózgu', 'cerebrovasculair accident (cva)', 'cva - cerebrovascular accident', 'apoplexie; cerebraal', 'cerebraal; accident', 'acidentes cerebrovasculares', 'stroke, cerebral', 'cerebraovascularis insultus', '脳卒中', 'cva - cerebrovascular accident (& unspecified [& stroke]) (disorder)', '後頭蓋卒中', 'accident vasculaire cerebral', 'vascular accident, brain', '卒中発作', 'mozková mrtvice', 'accident; cerebraal', '脳発症', 'cerebrovascularis esemény', 'ﾉｳｹｯｶﾝﾎｯｻnos', 'acv, sai', 'schlaganfall', 'ストローク', 'hjerneslag', 'cerebrovasculair accident', 'apopleksi/cerebrovaskulaer katastr', 'accident cérébrovasculaire', 'accidente cerebrovascular (trastorno)', 'accident vasculaire cérébral', 'онмк', 'aivohalvaus', 'zerebrovaskulärer insult', 'cerebral apoplexy, nos', 'acidente cerebral vascular', 'cerebrovascular accident (disorder)', 'acidente cerebrovascular', 'vascular cerebral accident', 'apoplexy, nos', 'hjerneslag/cerebrovask katastrofe', 'cva', 'beroerte', 'avc', '卒中', 'vascular accidents, brain', 'accidente vascular cerebral', 'apoplejía', 'cerebraal; apoplexie', 'cva (cerebral vascular accident)', 'cva (cerebrovascular accident)', 'strokes, cerebral', 'acidente vascular cerebral', 'mozková příhoda', 'apoplessia cerebrovascolare', 'schlaganfall, nicht als blutung oder infarkt bezeichnet', 'stroke/cerebrovascular accident', 'accident cerebrovascular', '脳出血発作症候群', 'apoplexia cerebral', 'strokes, cerebrovascular', 'cerebrovascular accident (disorder) [ambiguous]', '뇌졸중', 'accidente cerebrovascular', 'accidente cerebrovascolare', 'accident cerebrovasculair', 'erua moxi', 'accidente vascular encefálico', 'cerebrovasculair; accident', 'vascular brain accident', 'stroke, nos', 'avc (accident vasculaire cérébral)', 'vasculair accident van de hersenen', 'ataque', 'cva - cerebrovascular accident unspecified', 'apoplexie', 'apoplexie; beroerte', 'schlaganfall nnb', 'cévní mozková příhoda nos', 'acidente vascular cerebral soe', 'ataque cerebral', 'cerebral stroke', 'vaskulärer insult des gehirns', 'slaganfall', 'accidente vascular del cerebro', 'cerebral apoplexy', 'accidente cerebrovascular, no especificado (trastorno)', 'stroke, not specified as hemorrhage or infarction', 'stroke; apoplectic', 'ﾉｳｿｯﾁｭｳ', "attaque d'apoplexie", 'stroke, not specified as haemorrhage or infarction', 'apoplexy, cerebral', 'stroke syndrome', 'apoplektischer insult', 'acidente/doenca cerebrovascular', 'cerebrovasculair accident nao', 'cerebrovascular stroke', 'cerebrovaskulär apoplexi', 'cerebral strokes', 'accident ischémique cérébral', 'ictus cerebral', 'cerebrale beroerte', "in ...
# ranks: [('Neurology', 0.4360425), ('Cardiology/Vascular Diseases', 0.42245397), ('Trauma', 0.3741505), ('Nephrology', 0.3043946), ('Sleep', 0.3010249)]
#
# ======= Occupational Diseases ==========
# study: NCT02344485
# terms: {'primäres parkinson-syndrom', 'parkinsons dis lewy body', 'malattia di parkinson da corpi di lewy', 'maladie de parkinson', 'ｼﾝｾﾝﾏﾋ', 'schuettellaehmung', 'shaking palsy', 'primary parkinsonism', 'malattia del parkinson idiopatico', 'sindrome de parkinson', 'parkinson disease, idiopathic', 'primärer parkinsonismus', "parkinson's disease, nos", "parkinson's disease, idiopathic", "pd - parkinson's disease", 'parkinson s disease', 'paralisis agitante', 'maladie parkinsonienne à corps de lewy', 'doença de parkinson ne', 'enfermedad de parkinson (trastorno)', 'paralysis agitans parkinsonism', 'lewy body parkinson dis', "disease parkinson's", 'disease;parkinsons', 'morbo di parkinson', 'shaking; palsy', 'agitans; paralyse', 'parkinson-syndrom', 'дрожательный паралич', 'паркинсона синдром', 'syndrom parkinsonův', 'parkinsonisme, primair', 'lewy-body-ziekte', 'doença de parkinson', 'třaslavá obrna', 'schuddende verlamming', 'drżączka poraźna', 'ﾊﾟｰｷﾝｿﾝﾋﾞｮｳ', 'ﾊﾟｰｷﾝｿﾝﾋﾞｮｳnos', 'paralysis; agitans', 'lewy body parkinson disease', "disease disorders parkinson's", 'parkinson disease (diagnosis)', "diseases parkinson's", 'malattia di parkinson', 'enfermedad de parkinson, sai (trastorno)', 'parkinsonism, primary', "parkinsona bolezn'", 'идиопатический синдром паркинсонизма', 'синдром паркинсона', 'lewy-body-parkinson-krankheit', "parkinson's disease (disorder)", "parkinson's", "idiopathic parkinson's disease", 'parkinsonův syndrom', 'parkinson disease', 'doença de parkinson com corpos de lewy', '파킨슨 증후군', '파킨슨병', 'palsy; shaking', 'parkinson syndrom', 'parkinson kór', 'paralyse; agitans', 'parkinsonova nemoc nos', "disease parkinsons's", 'disease idiopathic parkinsons', 'parkinsonismo idiopático', '振戦麻痺', 'idiopathic parkinson disease', 'паралич дрожательный', 'parkinson-betegség', '파킨슨병 nos', 'パーキンソン氏病', 'idiopatická parkinsonova nemoc', 'morbo di parkinson nas', 'ﾊﾟｰｷﾝｿﾝｼｮｳｺｳｸﾞﾝ', 'morbus parkinson', 'parkinson disease (pd)', 'parkinsonova nemoc', '振顫麻痺', 'diseases parkinson', "parkinson's disease, lewy body", 'parkinsons ziekte', 'parkinson-syndroma', 'enfermedad de parkinson neom', 'パーキンソンモデル', 'enfermedad de parkinson', 'parálisis agitante', 'mal de parkinson', 'doença de parkinson soe', 'parkinsonisme primitif', 'parkinsons dis', 'parkinson-kór k.m.n.', "parkinson's disease", 'parkinsons disease', 'paralysis agitans <parkinsonism>', 'disease parkinson s', 'agitans; paralysis', 'paralysie agitante', 'paralisi agitante', 'enfermedad de parkinson idiopática', 'parkinson dis', 'パーキンソン症候群', 'parálisis temblorosa', 'parkinson syndrom nnb', 'parkinson dis idiopathic', 'idiopathische parkinson-krankheit', 'parkinsonismo primário', 'paralisia com tremor', 'parkinsonova bolest', 'parkinson`s disease', 'maladie de parkinson sai', 'パーキンソン病ｎｏｓ', "parkinson's syndrome", 'doenca de parkinson', 'parkinson-syndroom', "paralich drozhatel'nyi", "parkinson's disease nos (disorder)", 'parkinson syndroma', 'болезнь паркинсона', 'choroba parkinsona', 'maladie de parkinson idiopathique', "lewy body parkinson's disease", 'parkinsons sykdom', 'primaeres parkinson-syndrom', 'parkinsonin tauti', 'paralisia agitante', 'sindrome di parkinson', 'enfermedad de parkinson con cuerpos de lewy', 'palsy shaking', 'idiopathic parkinson dis', '떨림 마비', 'doença de parkinson idiopática', 'parkinson病', 'enfermedad de parkinson, sai', 'primární parkinsonismus', 'симптомы болезни паркинсона', "syndrome parkinson's", 'parkinson-kór', 'паркинсона болезнь', 'ziekte van parkinson nao', 'болезнь паркинсона бду', 'パーキンソン病', 'ziekte van parkinson', 'parkinsons sjukdom', "parkinson's disease nos", 'parkinson-os remegés', 'síndrome de parkinson', "bodies disease lewy parkinson's", 'parkinson disease lewy body', 'idiopathic parkinsons dis', 'idiopathische ziekte van parkinson', "parkinson's dis", 'idiopathic parkinsonism', 'diseases parkinsons', 'paralysis;agitans', 'parkinson-krankheit', 'syndrome de parkinson', 'paralysis agitans', 'parkinsons dis idiopathic', 'syndrom parkinson ...
# ranks: [('Occupational Diseases', 0.09017148), ('Dermatology', 0.079518326), ('Endocrinology', 0.042977296), ('Pharmacology/Toxicology', 0.017838214), ('Nutrition and Weight Loss', 0.016142849)]
#
# study: NCT02339064
# terms: {'primäres parkinson-syndrom', 'parkinsons dis lewy body', 'malattia di parkinson da corpi di lewy', 'maladie de parkinson', 'ｼﾝｾﾝﾏﾋ', 'schuettellaehmung', 'shaking palsy', 'primary parkinsonism', 'malattia del parkinson idiopatico', 'sindrome de parkinson', 'parkinson disease, idiopathic', 'primärer parkinsonismus', "parkinson's disease, nos", "parkinson's disease, idiopathic", "pd - parkinson's disease", 'parkinson s disease', 'paralisis agitante', 'maladie parkinsonienne à corps de lewy', 'doença de parkinson ne', 'enfermedad de parkinson (trastorno)', 'paralysis agitans parkinsonism', 'lewy body parkinson dis', "disease parkinson's", 'disease;parkinsons', 'morbo di parkinson', 'shaking; palsy', 'agitans; paralyse', 'parkinson-syndrom', 'дрожательный паралич', 'паркинсона синдром', 'syndrom parkinsonův', 'parkinsonisme, primair', 'lewy-body-ziekte', 'doença de parkinson', 'třaslavá obrna', 'schuddende verlamming', 'drżączka poraźna', 'ﾊﾟｰｷﾝｿﾝﾋﾞｮｳ', 'ﾊﾟｰｷﾝｿﾝﾋﾞｮｳnos', 'paralysis; agitans', 'lewy body parkinson disease', "disease disorders parkinson's", 'parkinson disease (diagnosis)', "diseases parkinson's", 'malattia di parkinson', 'enfermedad de parkinson, sai (trastorno)', 'parkinsonism, primary', "parkinsona bolezn'", 'идиопатический синдром паркинсонизма', 'синдром паркинсона', 'lewy-body-parkinson-krankheit', "parkinson's disease (disorder)", "parkinson's", "idiopathic parkinson's disease", 'parkinsonův syndrom', 'parkinson disease', 'doença de parkinson com corpos de lewy', '파킨슨 증후군', '파킨슨병', 'palsy; shaking', 'parkinson syndrom', 'parkinson kór', 'paralyse; agitans', 'parkinsonova nemoc nos', "disease parkinsons's", 'disease idiopathic parkinsons', 'parkinsonismo idiopático', '振戦麻痺', 'idiopathic parkinson disease', 'паралич дрожательный', 'parkinson-betegség', '파킨슨병 nos', 'パーキンソン氏病', 'idiopatická parkinsonova nemoc', 'morbo di parkinson nas', 'ﾊﾟｰｷﾝｿﾝｼｮｳｺｳｸﾞﾝ', 'morbus parkinson', 'parkinson disease (pd)', 'parkinsonova nemoc', '振顫麻痺', 'diseases parkinson', "parkinson's disease, lewy body", 'parkinsons ziekte', 'parkinson-syndroma', 'enfermedad de parkinson neom', 'パーキンソンモデル', 'enfermedad de parkinson', 'parálisis agitante', 'mal de parkinson', 'doença de parkinson soe', 'parkinsonisme primitif', 'parkinsons dis', 'parkinson-kór k.m.n.', "parkinson's disease", 'parkinsons disease', 'paralysis agitans <parkinsonism>', 'disease parkinson s', 'agitans; paralysis', 'paralysie agitante', 'paralisi agitante', 'enfermedad de parkinson idiopática', 'parkinson dis', 'パーキンソン症候群', 'parálisis temblorosa', 'parkinson syndrom nnb', 'parkinson dis idiopathic', 'idiopathische parkinson-krankheit', 'parkinsonismo primário', 'paralisia com tremor', 'parkinsonova bolest', 'parkinson`s disease', 'maladie de parkinson sai', 'パーキンソン病ｎｏｓ', "parkinson's syndrome", 'doenca de parkinson', 'parkinson-syndroom', "paralich drozhatel'nyi", "parkinson's disease nos (disorder)", 'parkinson syndroma', 'болезнь паркинсона', 'choroba parkinsona', 'maladie de parkinson idiopathique', "lewy body parkinson's disease", 'parkinsons sykdom', 'primaeres parkinson-syndrom', 'parkinsonin tauti', 'paralisia agitante', 'sindrome di parkinson', 'enfermedad de parkinson con cuerpos de lewy', 'palsy shaking', 'idiopathic parkinson dis', '떨림 마비', 'doença de parkinson idiopática', 'parkinson病', 'enfermedad de parkinson, sai', 'primární parkinsonismus', 'симптомы болезни паркинсона', "syndrome parkinson's", 'parkinson-kór', 'паркинсона болезнь', 'ziekte van parkinson nao', 'болезнь паркинсона бду', 'パーキンソン病', 'ziekte van parkinson', 'parkinsons sjukdom', "parkinson's disease nos", 'parkinson-os remegés', 'síndrome de parkinson', "bodies disease lewy parkinson's", 'parkinson disease lewy body', 'idiopathic parkinsons dis', 'idiopathische ziekte van parkinson', "parkinson's dis", 'idiopathic parkinsonism', 'diseases parkinsons', 'paralysis;agitans', 'parkinson-krankheit', 'syndrome de parkinson', 'paralysis agitans', 'parkinsons dis idiopathic', 'syndrom parkinson ...
# ...
# ranks: [('Pharmacology/Toxicology', 0.6701932), ('Psychiatry/Psychology', 0.6545869), ('Neurology', 0.63266253), ('Musculoskeletal', 0.6303817), ('Cardiology/Vascular Diseases', 0.62285155)]
#
# study: NCT03190954
# terms: {'opioid abuse', 'opioidabhaengigkeit', 'dépendance aux opiacés', '아편제 의존', 'dependence narcotic', 'addiction, opioid', 'зависимость от препаратов опиоидного типа', 'opioid abuse (diagnosis)', 'dependência tipo opióide, uso ne', 'trastorno relacionado con opiáceos', 'opioïden; misbruik', 'abuso di oppioidi', 'ｱﾍﾝﾙｲﾗﾝﾖｳ', 'dependence; opioids', 'opioids; dependence', 'opiaatmisbruik', 'зависимость от опиатов', 'dépendance aux opiacés, usage non précisé', 'dependence opiates', 'závislost na opioidech', 'opioid dependence (diagnosis)', 'アヘン類乱用', 'narcotic dependence', 'opiatavhengighet', 'dependencia de narcóticos', 'opioid típus függőség', 'ｱﾍﾝｻﾞｲｲｿﾞﾝ', 'opioidabhaengigkeit, nicht spezifizierte verwendung', 'narcodependencia', 'dependencia a opiodes no especificada', 'злоупотребление опиоидами', 'opioid addiction', 'opiodépendance', 'dependencia de opiáceos (trastorno)', 'opioidmissbruk', 'opioid abúzus', 'アヘン類依存、使用の詳細不明', '아편 유사제형 의존, 상세 불명의 사용', 'dipendenza da oppioidi', 'misbruik; opioïden', 'abuse; opioids', 'opioïd-type afhankelijkheid', 'unspecified opioid dependence', 'abuso de opióides', 'dependence, opiate', 'opioidmissbrauch', 'abuse, opioid', 'afhankelijkheid; opioïde', 'opioid dependences', 'opioid dependence (disorder)', 'dependencia de tipo opioide', 'dipendenza da oppiacei', 'opioid típus függőség, nem meghatározott használat', 'opioid type drug dependence', 'adicción a opiáceos', '[x]drug addiction - opioids', 'dependence on opiates', 'narcotism', 'afhankelijkheid van opiaten', 'opioid dependence', 'opioid type dependence, unspecified use', 'dependência de opiáceos', 'afhankelijkheid; opiaat', 'opiatberoende', 'opioid abuses', 'opiátová závislost', 'abuse opioids', 'opioid abuse (disorder)', 'зависимость от препаратов опиоидного типа, неуточненный характер употребления', 'opioid type dependence', 'dependência de opioides', 'adicciones a opiáceos', "abus d'opiacés", 'abuso de opiáceos', 'opioids; abuse', 'ｱﾍﾝﾙｲｲｿﾞﾝｼﾖｳﾉｼｮｳｻｲﾌﾒｲ', 'dependence, opioid', '아편 유사제형 의존', 'dependência de opioide, uso não especificado', 'abusos de opioides', 'ｱﾍﾝﾙｲｲｿﾞﾝ', 'dependência tipo opióide', 'addiction, opiate', 'závislost na opiátech', 'unspecified opioid dependence (disorder)', 'opioid addictions', 'adição a opiáceos', 'addiction opiate', 'opiat-abhängigkeit', 'dependencia de opiáceos', 'dipendenza da oppioidi, uso non specificato', 'dependencias de opiáceos', 'zneužívání opioidů', 'opioïd-type afhankelijkheid, niet-gespecificeerd gebruik', 'opioid type dependence, unspecified', 'dependencia de tipo opioide, uso no especificado', 'dependencia a opiodes no especificada (trastorno)', 'függőség, opiatok', 'abhaengigkeit von opiaten', 'opiatenafhankelijkheid', 'アヘン剤依存', 'závislost na opioidech, blíže neurčené užívání', 'abuso de opioides', 'abuso de opiáceos (trastorno)', 'dipendenza dagli oppiacei', 'opiate addiction', 'abúzus opioidů', '아편 유사제 남용', 'opioïden; afhankelijkheidssyndroom', 'アヘン類依存', 'dependence; opiate', 'opiate dependence', 'opioid dependence-unspec'}
# ranks: [('Pharmacology/Toxicology', 0.6701932), ('Psychiatry/Psychology', 0.6545869), ('Neurology', 0.63266253), ('Musculoskeletal', 0.6303817), ('Cardiology/Vascular Diseases', 0.62285155)]
#
# ======= Rare Diseases and Disorders ==========
# study: NCT04279314
# terms: {'disorder retts', 'autism-dementia-ataxia-loss of purposeful hand use syndrome', 'autisme-dementie-ataxie-verminderde handfunctie', 'autism dementia ataxia loss of purposeful hand use syndrome', '레트 증후군', 'rett-syndrom', 'retta sindrom', 'syndrome de rett', 'syndrome, rett', 'syndrom mit autismus, demenz, alexie und verlust von zweckmäßigen handbewegungen', 'disturbo di rett', "rett's syndrome", "rett's syndrome (diagnosis)", 'синдром ретта', 'rettova choroba', 'trastorno de rett', 'autismo, demencia, ataxia y pérdida intencionada del uso de la mano', '레트 장애', 'retts syndrome', 'cerebroatrophic hyperammonaemia', 'レット障害', 'rett syndrome', 'distúrbio de rett', 'rett disorder', 'síndrome de autismo-demência-ataxia-perda do uso proposital da mão', 'syndrome rett', 'hirnatrophische hyperammonämie', 'zespół retta', 'iperammoniemia cerebroartrofica', 'rett', 'hyperammonemias, cerebroatrophic', 'síndrome de rett', 'rettův syndrom', 'rett syndrome (rs, rts)', 'trastorno de rett (trastorno)', 'syndroom van rett', 'болезнь ретта', 'rettov sindrom', 'retts syndrom', 'cerebroatrophic hyperammonemia', 'síndrome de autismo-demência-ataxia-perda do uso intencional da mão', 'autism, dementia, ataxia, and loss of purposeful hand use', 'sindrome di rett', 'rett syndrome (disorder)', 'rts', 'ziekte van rett', 'rettin oireyhtymä', 'rett-betegség', 'ﾚｯﾄｼｮｳｺｳｸﾞﾝ', 'hyperammonemia, cerebroatrophic', 'hiperamonemia cerebroatrófica', 'レット症候群', 'ﾚｯﾄｼｮｳｶﾞｲ', 'rettsyndroom', 'rett syndrom', 'sr', "rett's disorder", 'retts dis', 'rett症候群', 'cerebroatrophic hyperammonemias', 'rtt', 'hyperammonemie, cerebroatrofische i', "syndrome, rett's", 'rts - rett syndrome', 'rett dis', "sindrome da autismo, demenza, atassia e perdita dell'uso finalistico della mano", 'ретта синдром', 'rett syndroma', "rett's disorder (disorder)"}
# ranks: [('Rare Diseases and Disorders', 0.56760144), ('Neurology', 0.5508511), ('Psychiatry/Psychology', 0.5152006), ('Pediatrics/Neonatology', 0.5125364), ('Sleep', 0.47760582)]
#
# study: NCT04514549
# terms: {'disorder retts', 'autism-dementia-ataxia-loss of purposeful hand use syndrome', 'autisme-dementie-ataxie-verminderde handfunctie', 'autism dementia ataxia loss of purposeful hand use syndrome', '레트 증후군', 'rett-syndrom', 'retta sindrom', 'syndrome de rett', 'syndrome, rett', 'syndrom mit autismus, demenz, alexie und verlust von zweckmäßigen handbewegungen', 'disturbo di rett', "rett's syndrome", "rett's syndrome (diagnosis)", 'синдром ретта', 'rettova choroba', 'trastorno de rett', 'autismo, demencia, ataxia y pérdida intencionada del uso de la mano', '레트 장애', 'retts syndrome', 'cerebroatrophic hyperammonaemia', 'レット障害', 'rett syndrome', 'distúrbio de rett', 'rett disorder', 'síndrome de autismo-demência-ataxia-perda do uso proposital da mão', 'syndrome rett', 'hirnatrophische hyperammonämie', 'zespół retta', 'iperammoniemia cerebroartrofica', 'rett', 'hyperammonemias, cerebroatrophic', 'síndrome de rett', 'rettův syndrom', 'rett syndrome (rs, rts)', 'trastorno de rett (trastorno)', 'syndroom van rett', 'болезнь ретта', 'rettov sindrom', 'retts syndrom', 'cerebroatrophic hyperammonemia', 'síndrome de autismo-demência-ataxia-perda do uso intencional da mão', 'autism, dementia, ataxia, and loss of purposeful hand use', 'sindrome di rett', 'rett syndrome (disorder)', 'rts', 'ziekte van rett', 'rettin oireyhtymä', 'rett-betegség', 'ﾚｯﾄｼｮｳｺｳｸﾞﾝ', 'hyperammonemia, cerebroatrophic', 'hiperamonemia cerebroatrófica', 'レット症候群', 'ﾚｯﾄｼｮｳｶﾞｲ', 'rettsyndroom', 'rett syndrom', 'sr', "rett's disorder", 'retts dis', 'rett症候群', 'cerebroatrophic hyperammonemias', 'rtt', 'hyperammonemie, cerebroatrofische i', "syndrome, rett's", 'rts - rett syndrome', 'rett dis', "sindrome da autismo, demenza, atassia e perdita dell'uso finalistico della mano", 'ретта синдром', 'rett syndroma', "rett's disorder (disorder)"}
# ranks: [('Rare Diseases and Disorders', 0.56760144), ('Neurology', 0.5508511), ('Psychiatry/Psychology', 0.5152006), ('Pediatrics/Neonatology', 0.5125364), ('Sleep', 0.47760582)]
#
# study: NCT04849052
# terms: {'âge mûr', 'mid-life', 'mediana edad (calificador)', 'mid life', 'middle-age, function (observable entity)', 'srednja dob', 'middelalder', 'mezza età', 'middle-age (finding)', 'mediana edad (hallazgo)', 'midlife', 'middle-age', 'střední věk', 'meia idade', 'middle-age (function)', 'mittleres lebensalter', 'cinquantaine', 'mediana edad', 'âge moyen', 'middle age (qualifier value)', 'mediana edad (entidad observable)', 'mediana edad (función)', 'middle age'}
# ranks: [('Rare Diseases and Disorders', 0.34201878), ('Nutrition and Weight Loss', 0.30225962), ('Psychiatry/Psychology', 0.29250783), ('Nephrology', 0.28472802), ('Disorders of Environmental Origin', 0.26577032)]
#
# study: NCT04988867
# terms: {'disorder retts', 'autism-dementia-ataxia-loss of purposeful hand use syndrome', 'autisme-dementie-ataxie-verminderde handfunctie', 'autism dementia ataxia loss of purposeful hand use syndrome', '레트 증후군', 'rett-syndrom', 'retta sindrom', 'syndrome de rett', 'syndrome, rett', 'syndrom mit autismus, demenz, alexie und verlust von zweckmäßigen handbewegungen', 'disturbo di rett', "rett's syndrome", "rett's syndrome (diagnosis)", 'синдром ретта', 'rettova choroba', 'trastorno de rett', 'autismo, demencia, ataxia y pérdida intencionada del uso de la mano', '레트 장애', 'retts syndrome', 'cerebroatrophic hyperammonaemia', 'レット障害', 'rett syndrome', 'distúrbio de rett', 'rett disorder', 'síndrome de autismo-demência-ataxia-perda do uso proposital da mão', 'syndrome rett', 'hirnatrophische hyperammonämie', 'zespół retta', 'iperammoniemia cerebroartrofica', 'rett', 'hyperammonemias, cerebroatrophic', 'síndrome de rett', 'rettův syndrom', 'rett syndrome (rs, rts)', 'trastorno de rett (trastorno)', 'syndroom van rett', 'болезнь ретта', 'rettov sindrom', 'retts syndrom', 'cerebroatrophic hyperammonemia', 'síndrome de autismo-demência-ataxia-perda do uso intencional da mão', 'autism, dementia, ataxia, and loss of purposeful hand use', 'sindrome di rett', 'rett syndrome (disorder)', 'rts', 'ziekte van rett', 'rettin oireyhtymä', 'rett-betegség', 'ﾚｯﾄｼｮｳｺｳｸﾞﾝ', 'hyperammonemia, cerebroatrophic', 'hiperamonemia cerebroatrófica', 'レット症候群', 'ﾚｯﾄｼｮｳｶﾞｲ', 'rettsyndroom', 'rett syndrom', 'sr', "rett's disorder", 'retts dis', 'rett症候群', 'cerebroatrophic hyperammonemias', 'rtt', 'hyperammonemie, cerebroatrofische i', "syndrome, rett's", 'rts - rett syndrome', 'rett dis', "sindrome da autismo, demenza, atassia e perdita dell'uso finalistico della mano", 'ретта синдром', 'rett syndroma', "rett's disorder (disorder)"}
# ranks: [('Rare Diseases and Disorders', 0.56760144), ('Neurology', 0.5508511), ('Psychiatry/Psychology', 0.5152006), ('Pediatrics/Neonatology', 0.5125364), ('Sleep', 0.47760582)]
#
# study: NCT05012475
# terms: {'disorder retts', 'autism-dementia-ataxia-loss of purposeful hand use syndrome', 'autisme-dementie-ataxie-verminderde handfunctie', 'autism dementia ataxia loss of purposeful hand use syndrome', '레트 증후군', 'rett-syndrom', 'retta sindrom', 'syndrome de rett', 'syndrome, rett', 'syndrom mit autismus, demenz, alexie und verlust von zweckmäßigen handbewegungen', 'disturbo di rett', "rett's syndrome", "rett's syndrome (diagnosis)", 'синдром ретта', 'rettova choroba', 'trastorno de rett', 'autismo, demencia, ataxia y pérdida intencionada del uso de la mano', '레트 장애', 'retts syndrome', 'cerebroatrophic hyperammonaemia', 'レット障害', 'rett syndrome', 'distúrbio de rett', 'rett disorder', 'síndrome de autismo-demência-ataxia-perda do uso proposital da mão', 'syndrome rett', 'hirnatrophische hyperammonämie', 'zespół retta', 'iperammoniemia cerebroartrofica', 'rett', 'hyperammonemias, cerebroatrophic', 'síndrome de rett', 'rettův syndrom', 'rett syndrome (rs, rts)', 'trastorno de rett (trastorno)', 'syndroom van rett', 'болезнь ретта', 'rettov sindrom', 'retts syndrom', 'cerebroatrophic hyperammonemia', 'síndrome de autismo-demência-ataxia-perda do uso intencional da mão', 'autism, dementia, ataxia, and loss of purposeful hand use', 'sindrome di rett', 'rett syndrome (disorder)', 'rts', 'ziekte van rett', 'rettin oireyhtymä', 'rett-betegség', 'ﾚｯﾄｼｮｳｺｳｸﾞﾝ', 'hyperammonemia, cerebroatrophic', 'hiperamonemia cerebroatrófica', 'レット症候群', 'ﾚｯﾄｼｮｳｶﾞｲ', 'rettsyndroom', 'rett syndrom', 'sr', "rett's disorder", 'retts dis', 'rett症候群', 'cerebroatrophic hyperammonemias', 'rtt', 'hyperammonemie, cerebroatrofische i', "syndrome, rett's", 'rts - rett syndrome', 'rett dis', "sindrome da autismo, demenza, atassia e perdita dell'uso finalistico della mano", 'ретта синдром', 'rett syndroma', "rett's disorder (disorder)"}
# ranks: [('Rare Diseases and Disorders', 0.56760144), ('Neurology', 0.5508511), ('Psychiatry/Psychology', 0.5152006), ('Pediatrics/Neonatology', 0.5125364), ('Sleep', 0.47760582)]
#
# ======= Family Medicine ==========
# study: NCT04549129
# terms: {'dojenje', 'amamentação', 'infant breast fed', 'kojení', 'amamentado', 'breast feed', 'breastfeeding', 'gi bryst', 'breast feedings', '母乳外来', '母乳育児', '母乳栄養法', 'amning', 'lactancia', 'lactancia (hallazgo)', 'lactancia materna', 'lactancia materna (función)', '乳房管理', 'allaitement au sein', 'breastfed', 'amamantamiento', 'breastfeed', 'breast fed', 'szoptatás', 'nursing', 'bf - breast fed', 'breastfeedings', 'breast feeding (function)', '母乳栄養', '母乳摂取量', 'żywienie niemowląt naturalne', '哺乳(母乳栄養)', 'infant breastfed', 'amamantado', 'breast feeding, function (observable entity)', 'lactancia materna (entidad observable)', 'borstvoeding', 'aleitamento materno', 'грудное вскармливание', 'breast fed infant', 'alimentado no peito', 'lactation', 'allaitement naturel', '모유 수유', 'alimentado a pecho (hallazgo)', 'alimentação ao peito', 'breast fed (finding)', '母乳保育', 'voeding, borst-', 'amming', 'stillen', 'allattamento al seno', 'alimentación al pecho', 'breast feeding, nos', 'bf - breastfeeding', 'allaitement', 'alimentado a pecho', 'grudnoe vskarmlivanie', 'bf - breastfed', 'allaitement maternel', 'breasting feeding', 'ﾎﾞﾆｭｳｴｲﾖｳﾎｳ', 'alimentado ao peito', '乳頭トラブル', '母乳運搬', 'karmienie piersią', 'breast fed infants', 'imetys', '母乳哺育', 'aleitamento', 'bf - breast-feeding', 'ほ乳(母乳栄養)', 'amme', 'breast feeding'}
# ranks: [('Family Medicine', 0.44886082), ('Internal Medicine', 0.4279473), ('Disorders of Environmental Origin', 0.41369474), ('Psychiatry/Psychology', 0.4003268), ('Nephrology', 0.37787765)]
#
# study: NCT04578925
# terms: {'dojenje', 'amamentação', 'infant breast fed', 'kojení', 'amamentado', 'breast feed', 'breastfeeding', 'gi bryst', 'breast feedings', '母乳外来', '母乳育児', '母乳栄養法', 'amning', 'lactancia', 'lactancia (hallazgo)', 'lactancia materna', 'lactancia materna (función)', '乳房管理', 'allaitement au sein', 'breastfed', 'amamantamiento', 'breastfeed', 'breast fed', 'szoptatás', 'nursing', 'bf - breast fed', 'breastfeedings', 'breast feeding (function)', '母乳栄養', '母乳摂取量', 'żywienie niemowląt naturalne', '哺乳(母乳栄養)', 'infant breastfed', 'amamantado', 'breast feeding, function (observable entity)', 'lactancia materna (entidad observable)', 'borstvoeding', 'aleitamento materno', 'грудное вскармливание', 'breast fed infant', 'alimentado no peito', 'lactation', 'allaitement naturel', '모유 수유', 'alimentado a pecho (hallazgo)', 'alimentação ao peito', 'breast fed (finding)', '母乳保育', 'voeding, borst-', 'amming', 'stillen', 'allattamento al seno', 'alimentación al pecho', 'breast feeding, nos', 'bf - breastfeeding', 'allaitement', 'alimentado a pecho', 'grudnoe vskarmlivanie', 'bf - breastfed', 'allaitement maternel', 'breasting feeding', 'ﾎﾞﾆｭｳｴｲﾖｳﾎｳ', 'alimentado ao peito', '乳頭トラブル', '母乳運搬', 'karmienie piersią', 'breast fed infants', 'imetys', '母乳哺育', 'aleitamento', 'bf - breast-feeding', 'ほ乳(母乳栄養)', 'amme', 'breast feeding'}
# ranks: [('Family Medicine', 0.44886082), ('Internal Medicine', 0.4279473), ('Disorders of Environmental Origin', 0.41369474), ('Psychiatry/Psychology', 0.4003268), ('Nephrology', 0.37787765)]
